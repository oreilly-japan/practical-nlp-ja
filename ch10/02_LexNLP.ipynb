# %% [markdown]
# # LexNLPを用いた法律テキストからの情報抽出
#
# このノートブックでは、[LexNLP](https://lexpredict-lexnlp.readthedocs.io/en/latest/)を使って、法律テキストから情報抽出をする方法を紹介します。LexNLPは、オープンソースの情報抽出のためのツールです。

# %% [markdown]
# ## 準備

# %% [markdown]
# ### パッケージのインストール
#
# パッケージをインストールしたら、ランタイムを再起動しましょう。

# %%
# !pip install -q lexnlp==1.8.0 textract==1.6.4
# !pip install -qU pandas nltk
# Out:
#      |████████████████████████████████| 1.4 MB 5.2 MB/s
#      |████████████████████████████████| 61 kB 382 kB/s
#      |████████████████████████████████| 72 kB 1.4 MB/s
#      |████████████████████████████████| 14.5 MB 14.9 MB/s
#      |████████████████████████████████| 10.1 MB 47.8 MB/s
#      |████████████████████████████████| 24.2 MB 1.6 MB/s
#      |████████████████████████████████| 101 kB 10.6 MB/s
#      |████████████████████████████████| 660 kB 40.4 MB/s
#      |████████████████████████████████| 238 kB 50.7 MB/s
#      |████████████████████████████████| 352 kB 56.4 MB/s
#      |████████████████████████████████| 294 kB 49.3 MB/s
#      |████████████████████████████████| 106 kB 57.9 MB/s
#      |████████████████████████████████| 111 kB 56.0 MB/s
#      |████████████████████████████████| 69 kB 6.6 MB/s
#      |████████████████████████████████| 5.6 MB 56.6 MB/s
#      |████████████████████████████████| 10.1 MB 10.8 MB/s
#      |████████████████████████████████| 32.8 MB 111 kB/s
#      |████████████████████████████████| 103 kB 58.2 MB/s
#      |████████████████████████████████| 2.0 MB 37.5 MB/s
#      |████████████████████████████████| 132 kB 53.0 MB/s
#      |████████████████████████████████| 128 kB 55.8 MB/s
#      |████████████████████████████████| 112 kB 32.3 MB/s
#      |████████████████████████████████| 73 kB 2.5 MB/s
#      |████████████████████████████████| 149 kB 46.8 MB/s
#      |████████████████████████████████| 70 kB 8.6 MB/s
#      |████████████████████████████████| 339 kB 57.9 MB/s
#   Building wheel for textract (setup.py) ... done
#   Building wheel for EbookLib (setup.py) ... done
#   Building wheel for nltk (setup.py) ... done
#   Building wheel for pycountry (setup.py) ... done
#   Building wheel for us (setup.py) ... done
#   Building wheel for jellyfish (setup.py) ... done
#   Building wheel for docx2txt (setup.py) ... done
#   Building wheel for compressed-rtf (setup.py) ... done
#   Building wheel for olefile (setup.py) ... done
#   Building wheel for python-pptx (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 0.18.2 requires pandas>=1.0, but you have pandas 0.24.2 which is incompatible.
# plotnine 0.6.0 requires pandas>=0.25.0, but you have pandas 0.24.2 which is incompatible.
# mizani 0.6.0 requires pandas>=0.25.0, but you have pandas 0.24.2 which is incompatible.
# imbalanced-learn 0.8.1 requires scikit-learn>=0.24, but you have scikit-learn 0.23.1 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 0.24.2 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.24.0 which is incompatible.
# google-colab 1.0.0 requires six~=1.15.0, but you have six 1.12.0 which is incompatible.
# google-api-python-client 1.12.8 requires six<2dev,>=1.13.0, but you have six 1.12.0 which is incompatible.
# google-api-core 1.26.3 requires six>=1.13.0, but you have six 1.12.0 which is incompatible.
# fbprophet 0.7.1 requires pandas>=1.0.4, but you have pandas 0.24.2 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
#      |████████████████████████████████| 11.3 MB 5.5 MB/s
#      |████████████████████████████████| 1.5 MB 48.1 MB/s
#      |████████████████████████████████| 749 kB 45.8 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lexnlp 1.8.0 requires nltk==3.5, but you have nltk 3.6.5 which is incompatible.
# lexnlp 1.8.0 requires pandas==0.24.2, but you have pandas 1.3.4 which is incompatible.
# lexnlp 1.8.0 requires regex==2020.7.14, but you have regex 2021.11.10 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.4 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.24.0 which is incompatible.
# google-colab 1.0.0 requires six~=1.15.0, but you have six 1.12.0 which is incompatible.
# datefinder-lexpredict 0.6.2.1 requires regex==2020.7.14, but you have regex 2021.11.10 which is incompatible.

# %% [markdown]
# ### インポート
#
# モジュールをインポートします。
# `lexnlp.extract`モジュールには、非構造化テキストから構造化されたデータを抽出するためのメソッドが含まれています。日付や金額などさまざまな種類のデータを抽出できるので、このあとやってみましょう。`lexnlp.nlp`モジュールには、単語分割やステミング、見出し語化など、自然言語処理タスクをサポートするメソッドが含まれています。
#
#
#
# - [lexnlp.extract: Extracting structured data from unstructured text](https://lexpredict-lexnlp.readthedocs.io/en/latest/modules/extract/extract.html)
# - [lexnlp.nlp: Natural language processing](https://lexpredict-lexnlp.readthedocs.io/en/latest/modules/nlp/nlp.html)

# %%
from pprint import pprint

import lexnlp.extract.en.acts
import lexnlp.extract.en.amounts
import lexnlp.extract.en.money
import lexnlp.extract.en.dates
import lexnlp.extract.en.ratios
import lexnlp.extract.en.definitions
import lexnlp.extract.en.copyright
import lexnlp.extract.en.durations
import lexnlp.nlp.en.tokens
import lexnlp.nlp.en.segments.sections
import lexnlp.nlp.en.transforms.tokens
import nltk
import pandas as pd
import textract
nltk.download("punkt")
nltk.download("averaged_perceptron_tagger")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %% [markdown]
# ### データのアップロード
#
# 本章のフォルダ内にある`test - Copy.docs`をアップロードします。

# %%
from google.colab import files
test_upload = files.upload()
# Out:
#      <input type="file" id="files-3c80bfe0-8034-4d74-9c98-0e47dd6dfd32" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c80bfe0-8034-4d74-9c98-0e47dd6dfd32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test - Copy.docx to test - Copy.docx

# %% [markdown]
# `.docs`を文字列に変換しておきましょう。

# %%
text = textract.process("test - Copy.docx").decode("utf-8")
type(text)
# Out:
# str

# %% [markdown]
# ## 法律名（Acts）の抽出
#
# `lexnlp.extract.en.acts`モジュールを用いて、テキストから法律名（Act）を抽出できます。法律名の例としては以下が挙げられます。
#
# - Advancing Hope Act
# - AGOA Acceleration Act of 2004
# - section 12 of the Agricultural Act of 1954
# - sections 751(a)(1) and 777(i)(1) of the Act

# %%
data_contract = list(lexnlp.extract.en.acts.get_acts(text))
pprint(data_contract)

df = pd.DataFrame(data=data_contract, columns=data_contract[0].keys())
df["Act_annotations"] = list(lexnlp.extract.en.acts.get_acts_annotations(text))
print(df.head(10))
# Out:
# [{'act_name': 'Securities Exchange Act',
#   'ambiguous': False,
#   'location_end': 6264,
#   'location_start': 6233,
#   'section': '',
#   'value': 'Securities Exchange Act of 1934',
#   'year': '1934'},
#  {'act_name': 'Securities Exchange Act',
#   'ambiguous': False,
#   'location_end': 6377,
#   'location_start': 6346,
#   'section': '',
#   'value': 'Securities Exchange Act of 1934',
#   'year': '1934'},
#  {'act_name': 'Securities Act',
#   'ambiguous': False,
#   'location_end': 9176,
#   'location_start': 9158,
#   'section': '',
#   'value': 'Securities Act.\n\n“',
#   'year': ''},
#  {'act_name': 'Securities Act',
#   'ambiguous': False,
#   'location_end': 15419,
#   'location_start': 15403,
#   'section': '',
#   'value': 'Securities Act, ',
#   'year': ''},
#  {'act_name': 'Securities Act',
#   'ambiguous': False,
#   'location_end': 15707,
#   'location_start': 15691,
#   'section': '',
#   'value': 'Securities Act, ',
#   'year': ''},
#  {'act_name': 'Securities Act',
#   'ambiguous': False,
#   'location_end': 15821,
#   'location_start': 15806,
#   'section': '',
#   'value': 'Securities Act ',
#   'year': ''}]
#    location_start  ...                    Act_annotations
# 0            6233  ...     [act] at (6233..6264), loc: en
# 1            6346  ...     [act] at (6346..6377), loc: en
# 2            9158  ...     [act] at (9158..9176), loc: en
# 3           15403  ...   [act] at (15403..15419), loc: en
# 4           15691  ...   [act] at (15691..15707), loc: en
# 5           15806  ...   [act] at (15806..15821), loc: en
#
# [6 rows x 8 columns]

# %% [markdown]
# ## 量（Amounts）の抽出
#
# `lexnlp.extract.en.amounts`モジュールを使うことで、テキストから量（Amount）に関係する情報を抽出できます。たとえば、以下が挙げられます。
#
# - THIRTY-SIX THOUSAND TWO-HUNDRED SIXTY-SIX AND 2/100
# - total 2 million people
# - total 2.035 billion tons of
# - fifteen cats
# - 20,000,000
# - thirty-five million units
# - 10K files
# - 1 trill

# %%
amts = list(lexnlp.extract.en.amounts.get_amounts(text))
locs = list(lexnlp.extract.en.amounts.get_amount_annotations(text))
pprint(amts)

data_amts = list(zip(amts, locs))
df = pd.DataFrame(data=data_amts, columns=["Amount", "Location in Contract"])
print(df.head())
# Out:
# [Decimal('1933.0'),
#  Decimal('1000000.0'),
#  Decimal('19.0'),
#  Decimal('2.0'),
#  Decimal('2022.0'),
#  Decimal('1.0'),
#  Decimal('1.0'),
#  Decimal('100000.0'),
#  Decimal('1.0'),
#  Decimal('1.0'),
#  Decimal('2.0'),
#  Decimal('1.0'),
#  Decimal('1.0'),
#  Decimal('1.0'),
#  Decimal('1.0'),
#  Decimal('2.0'),
#  Decimal('13.0'),
#  Decimal('14.0'),
#  Decimal('1934.0'),
#  Decimal('3.0'),
#  Decimal('1934.0'),
#  Decimal('50.0'),
#  Decimal('1.0'),
#  Decimal('3.0'),
#  Decimal('3.0'),
#  Decimal('1.0'),
#  Decimal('4.0'),
#  Decimal('501.0'),
#  Decimal('5.0'),
#  Decimal('1.0'),
#  Decimal('50.0'),
#  Decimal('48.0'),
#  Decimal('1.0'),
#  Decimal('1.0'),
#  Decimal('1.0'),
#  Decimal('1.0'),
#  Decimal('304.0'),
#  Decimal('305.0'),
#  Decimal('306.0'),
#  Decimal('354.0'),
#  Decimal('368.0'),
#  Decimal('1036.0'),
#  Decimal('1202.0'),
#  Decimal('1986.0')]
#       Amount              Location in Contract
# 0     1933.0   [amount] at (113..119), loc: en
# 1  1000000.0   [amount] at (604..612), loc: en
# 2       19.0   [amount] at (648..651), loc: en
# 3        2.0   [amount] at (651..654), loc: en
# 4     2022.0   [amount] at (654..660), loc: en

# %% [markdown]
# ## 日付（Dates）の抽出
#
# `lexnlp.extract.en.dates`モジュールを使うと、日付を抽出できます。以下は日付の例です。
#
# - February 1, 1998
# - 2017-06-01
# - 1st day of June, 2017
# - 31 October 2016
# - 15th of March 2000

# %%
data_dates = list(lexnlp.extract.en.dates.get_dates(text))
df = pd.DataFrame(data=data_dates, columns=["Date"])
print(df.head())
# Out:
#          Date
# 0  2022-02-19

# %% [markdown]
# ## 金額（Money）の抽出
#
# `lexnlp.extract.en.money`モジュールを使うと、金額を抽出できます。以下は金額の例です。
#
#  five dollars
# - 5 dollars
# - 5 USD
# - $5

# %%
data_money = list(lexnlp.extract.en.money.get_money(text))
df = pd.DataFrame(data=data_money, columns=["Amount", "Currency"])
print(df.head())
# Out:
#       Amount Currency
# 0  1000000.0      USD
# 1   100000.0      USD
# 2        2.0      USD

# %% [markdown]
# ## 比率（Ratios）の抽出
#
# `lexnlp.extract.en.ratios`モジュールを使うことで、比率を抽出できます。以下は比率の例です。
#
# - 3:1
# - 3.0:1.0
# - three to one

# %%
data_ratios = list(lexnlp.extract.en.ratios.get_ratios(text))
df = pd.DataFrame(data=data_ratios, columns=["Ratios"])
print(df.head())
print("No ratios in the contract")
# Out:
# Empty DataFrame
# Columns: [Ratios]
# Index: []
# No ratios in the contract

# %% [markdown]
# ## 定義（Definitions）の抽出
#
# `lexnlp.extract.en.definitions`モジュールを使うことで、テキストから定義を抽出できます。以下の文における`X`が定義の例として挙げられます。
#
# - X shall [not] include …
# - X shall have the meaning …
# - X is hereby changed to …
# - X shall be interpreted …
# - X shall for purposes …
# - X shall be deemed to …
# - X shall refer to …
# - X shall mean …
# - X is defined …
# - The word “X” includes every description of …
# - The term “X” means …
# - Description of term (the “x”)

# %%
data_acts = list(lexnlp.extract.en.definitions.get_definitions(text))
df = pd.DataFrame(data=data_acts, columns=["Acts"])
print(df.head(20))
# Out:
#                        Acts
# 0            SECURITIES ACT
# 1                  Investor
# 2           Purchase Amount
# 3         Conversion Amount
# 4           Cash-Out Amount
# 5             Capital Stock
# 6         Change of Control
# 7     Converting Securities
# 8         Dissolution Event
# 9           Dividend Amount
# 10         Equity Financing
# 11  Initial Public Offering
# 12          Liquidity Event
# 13          Liquidity Price
# 14                  Options
# 15                 Proceeds
# 16         Promised Options
# 17                     Safe
# 18      SafePreferred Stock
# 19               Safe Price

# %% [markdown]
# ## コピーライト（Copyrights）の抽出
#
# `lexnlp.extract.en.copyright`モジュールを使うことでコピーライトを抽出できます。

# %%
data_cp_ann = list(lexnlp.extract.en.copyright.get_copyright_annotations(text))

data_cp = list(lexnlp.extract.en.copyright.get_copyright(text))

df = pd.DataFrame(
    data=list(zip(data_cp, data_cp_ann)),
    columns=["CopyRight Annotations", "CopyRight data"],
)
print(df.head())
# Out:
#             CopyRight Annotations                   CopyRight data
# 0  ((c), None, Dissolution Event)  Dissolution Event, (3862, 3883)

# %% [markdown]
# ## 期間（Durations）の抽出
#
# `lexnlp.extract.en.durations`モジュールを使うことで、期間を抽出できます。

# %%
data_dur = list(lexnlp.extract.en.durations.get_durations(text))
data_dur_ann = list(lexnlp.extract.en.durations.get_duration_annotations_list(text))

df = pd.DataFrame(
    data=list(zip(data_dur, data_dur_ann)), columns=["Durations", "Duration Annotation"]
)
print(df.head())
# Out:
#            Durations                     Duration Annotation
# 0  (hour, 48.0, 2.0)   [duration] at (17772..17781), loc: en

# %% [markdown]
# ## トークンの抽出
#
# `get_nouns`や`get_verbs`などのメソッドを使うことで、テキストから名詞や動詞を抽出できます。また、ステミングや見出し語化などの処理もできます。

# %%
print("Noun")
print(list(lexnlp.nlp.en.tokens.get_nouns(text))[:10])

print("Stemming")
print(
    lexnlp.nlp.en.tokens.get_stem_list(
        text, stemmer=nltk.stem.lancaster.LancasterStemmer()
    )[:10]
)

print("Lematization")
print(list(lexnlp.nlp.en.tokens.get_verbs(text, lemmatize=True))[:10])
# Out:
# Noun
# ['THIS', 'INSTRUMENT', 'AND', 'ANY', 'SECURITIES', 'ISSUABLE', 'PURSUANT', 'HERETO', 'HAVE', 'NOT']
# Stemming
# ['thi', 'instru', 'and', 'any', 'sec', 'issu', 'pursu', 'hereto', 'hav', 'not']
# Lematization
# ['s', 'describe', 'be', 'agree', 'have', 'modify', 'fill', 'bracket', 'be', 'define']

# %% [markdown]
# ## セクションの抽出
#
# `lexnlp.nlp.en.segments.sections`モジュールを使うことで、テキストからセクションを抽出できます。

# %%
pprint(list(lexnlp.nlp.en.segments.sections.get_sections(text)))
# Out:
# []

# %% [markdown]
# ## Bigramの分布

# %%
pprint(dict(lexnlp.nlp.en.transforms.tokens.get_bigram_distribution(text)))
# Out:
# {('$', '100000.'): 1,
#  ('$', '1000000'): 1,
#  ('%', 'of'): 2,
#  ('(', '1'): 1,
#  ('(', '2'): 1,
#  ('(', 'A'): 3,
#  ('(', 'B'): 3,
#  ('(', 'C'): 1,
#  ('(', 'Signature'): 1,
#  ('(', 'Simple'): 1,
#  ('(', 'THE'): 1,
#  ('(', 'a'): 5,
#  ('(', 'and'): 1,
#  ('(', 'as'): 1,
#  ('(', 'b'): 5,
#  ('(', 'but'): 1,
#  ('(', 'c'): 4,
#  ('(', 'd'): 7,
#  ('(', 'e'): 3,
#  ('(', 'even'): 1,
#  ('(', 'except'): 1,
#  ('(', 'excluding'): 1,
#  ('(', 'f'): 1,
#  ('(', 'g'): 1,
#  ('(', 'i'): 15,
#  ('(', 'ii'): 16,
#  ('(', 'iii'): 7,
#  ('(', 'in'): 1,
#  ('(', 'including'): 3,
#  ('(', 'or'): 2,
#  ('(', 's'): 2,
#  ('(', 'subject'): 1,
#  ('(', 'that'): 1,
#  ('(', 'the'): 4,
#  ('(', 'to'): 1,
#  ('(', 'treating'): 1,
#  ('(', 'within'): 1,
#  ('(', 'without'): 3,
#  ('(', 'x'): 1,
#  ('(', 'y'): 1,
#  (')', ')'): 2,
#  (')', ','): 7,
#  (')', '.'): 6,
#  (')', '.If'): 1,
#  (')', ':'): 3,
#  (')', ';'): 2,
#  (')', 'All'): 1,
#  (')', 'Any'): 2,
#  (')', 'Dissolution'): 1,
#  (')', 'Equity'): 1,
#  (')', 'IN'): 1,
#  (')', 'In'): 1,
#  (')', 'Junior'): 1,
#  (')', 'Liquidation'): 1,
#  (')', 'Liquidity'): 1,
#  (')', 'Neither'): 1,
#  (')', 'No'): 1,
#  (')', 'On'): 1,
#  (')', 'Promised'): 1,
#  (')', 'Senior'): 1,
#  (')', 'THIS'): 1,
#  (')', 'Termination.'): 1,
#  (')', 'The'): 7,
#  (')', 'To'): 1,
#  (')', 'a'): 4,
#  (')', 'above'): 1,
#  (')', 'and'): 2,
#  (')', 'any'): 5,
#  (')', 'convertible'): 2,
#  (')', 'does'): 1,
#  (')', 'immediately'): 1,
#  (')', 'in'): 1,
#  (')', 'is'): 1,
#  (')', 'issued'): 2,
#  (')', 'its'): 1,
#  (')', 'junior'): 1,
#  (')', 'necessary'): 1,
#  (')', 'of'): 2,
#  (')', 'on'): 2,
#  (')', 'only'): 1,
#  (')', 'or'): 2,
#  (')', 'other'): 1,
#  (')', 'promised'): 1,
#  (')', 'result'): 2,
#  (')', 'such'): 1,
#  (')', 'sufficient'): 1,
#  (')', 'that'): 1,
#  (')', 'the'): 15,
#  (')', 'to'): 1,
#  (')', 'treated'): 1,
#  (')', 'under'): 1,
#  (')', 'violate'): 1,
#  (')', 'where'): 1,
#  (')', 'while'): 1,
#  (',', '('): 4,
#  (',', '1036'): 1,
#  (',', '305'): 1,
#  (',', '306'): 1,
#  (',', '354'): 1,
#  (',', '368'): 1,
#  (',', 'AS'): 1,
#  (',', 'Anaxia'): 1,
#  (',', 'OR'): 1,
#  (',', 'PLEDGED'): 1,
#  (',', 'Promised'): 1,
#  (',', 'RSUs'): 1,
#  (',', 'SARs'): 1,
#  (',', 'SOLD'): 1,
#  (',', 'a'): 2,
#  (',', 'addressed'): 1,
#  (',', 'and'): 12,
#  (',', 'any'): 3,
#  (',', 'as'): 7,
#  (',', 'asset'): 1,
#  (',', 'at'): 1,
#  (',', 'available'): 1,
#  (',', 'becomes'): 1,
#  (',', 'by'): 2,
#  (',', 'can'): 1,
#  (',', 'controls'): 1,
#  (',', 'copyrights'): 1,
#  (',', 'could'): 1,
#  (',', 'delivery'): 1,
#  (',', 'directly'): 1,
#  (',', 'dissolution'): 1,
#  (',', 'due'): 2,
#  (',', 'enforceable'): 2,
#  (',', 'equal'): 1,
#  (',', 'except'): 3,
#  (',', 'forfeiture'): 1,
#  (',', 'further'): 1,
#  (',', 'granting'): 1,
#  (',', 'having'): 1,
#  (',', 'however'): 1,
#  (',', 'if'): 2,
#  (',', 'illegal'): 1,
#  (',', 'immediately'): 1,
#  (',', 'in'): 4,
#  (',', 'including'): 6,
#  (',', 'individually'): 1,
#  (',', 'information'): 1,
#  (',', 'insolvency'): 2,
#  (',', 'intended'): 1,
#  (',', 'is'): 2,
#  (',', 'issues'): 1,
#  (',', 'its'): 1,
#  (',', 'lease'): 2,
#  (',', 'license'): 1,
#  (',', 'licenses'): 1,
#  (',', 'limited'): 1,
#  (',', 'managing'): 1,
#  (',', 'merger'): 1,
#  (',', 'nor'): 1,
#  (',', 'not'): 1,
#  (',', 'notwithstanding'): 1,
#  (',', 'of'): 2,
#  (',', 'officer'): 1,
#  (',', 'on'): 2,
#  (',', 'only'): 1,
#  (',', 'or'): 17,
#  (',', 'other'): 4,
#  (',', 'others.'): 1,
#  (',', 'power'): 1,
#  (',', 'preferences'): 1,
#  (',', 'prejudiced'): 1,
#  (',', 'privileges'): 1,
#  (',', 'processes'): 1,
#  (',', 'provided'): 3,
#  (',', 'purchased'): 1,
#  (',', 'pursuant'): 1,
#  (',', 'restricted'): 1,
#  (',', 'rule'): 2,
#  (',', 'service'): 1,
#  (',', 'similar'): 1,
#  (',', 'statute'): 1,
#  (',', 'subject'): 1,
#  (',', 'such'): 2,
#  (',', 'that'): 4,
#  (',', 'the'): 17,
#  (',', 'then'): 1,
#  (',', 'therefore'): 1,
#  (',', 'this'): 3,
#  (',', 'to'): 2,
#  (',', 'trade'): 2,
#  (',', 'trademarks'): 1,
#  (',', 'until'): 1,
#  (',', 'valid'): 1,
#  (',', 'validly'): 1,
#  (',', 'vested'): 1,
#  (',', 'waived'): 2,
#  (',', 'waiver'): 1,
#  (',', 'warrants'): 1,
#  (',', 'where'): 1,
#  (',', 'whether'): 1,
#  (',', 'which'): 2,
#  (',', 'with'): 2,
#  (',', 'without'): 7,
#  ('.', '('): 3,
#  ('.', '2.Definitions'): 1,
#  ('.', 'This'): 1,
#  ('.', '“'): 1,
#  ('.If', 'any'): 1,
#  ('//ycombinator.com/documents', 'and'): 1,
#  ('1', '('): 4,
#  ('1', ')'): 1,
#  ('1.', '('): 1,
#  ('1.Events', '('): 1,
#  ('1.However', ','): 1,
#  ('100000.', 'See'): 1,
#  ('1000000', '('): 1,
#  ('1036', 'and'): 1,
#  ('1202', 'of'): 1,
#  ('13', '('): 1,
#  ('13d-3', 'under'): 1,
#  ('14', '('): 1,
#  ('19-02-2022', ','): 1,
#  ('1933', ','): 1,
#  ('1934', ','): 2,
#  ('1986', ','): 1,
#  ('2', ')'): 1,
#  ('2.Definitions', '“'): 1,
#  ('2for', 'certain'): 1,
#  ('3', '('): 1,
#  ('3.Company', 'Representations'): 1,
#  ('304', ','): 1,
#  ('305', ','): 1,
#  ('306', ','): 1,
#  ('354', ','): 1,
#  ('368', ','): 1,
#  ('4.Investor', 'Representations'): 1,
#  ('48', 'hours'): 1,
#  ('5.Miscellaneous', '('): 1,
#  ('50', '%'): 2,
#  ('501', 'of'): 1,
#  (':', '('): 8,
#  (':', '//ycombinator.com/documents'): 1,
#  (':', 'Bob'): 1,
#  (':', 'By'): 1,
#  (':', 'Includes'): 2,
#  (':', 'Old'): 1,
#  (':', 'Psiayn'): 1,
#  (':', 'Star'): 1,
#  (':', 'dio'): 1,
#  (':', 'reddit'): 2,
#  (':', 'vegito'): 1,
#  (';', '('): 4,
#  (';', 'Includes'): 5,
#  (';', 'and'): 6,
#  (';', 'andprovided'): 1,
#  (';', 'or'): 3,
#  (';', 'provided'): 2,
#  ('@', 'reddif.com'): 1,
#  ('@', 'xyz.com'): 1,
#  ('A', ')'): 3,
#  ('ACT', 'AND'): 1,
#  ('ACT', 'OF'): 1,
#  ('ACT', '”'): 1,
#  ('AMENDED', '('): 1,
#  ('AN', 'EFFECTIVE'): 1,
#  ('AN', 'EXEMPTION'): 1,
#  ('AND', 'ANY'): 1,
#  ('AND', 'APPLICABLE'): 1,
#  ('AND', 'UNDER'): 1,
#  ('ANY', 'SECURITIES'): 1,
#  ('APPLICABLE', 'STATE'): 1,
#  ('AS', 'AMENDED'): 1,
#  ('AS', 'PERMITTED'): 1,
#  ('Act', ','): 2,
#  ('Act', 'and'): 1,
#  ('Act', 'of'): 2,
#  ('Act.', '“'): 1,
#  ('Address', ':'): 2,
#  ('Agreement', 'for'): 1,
#  ('All', 'rights'): 1,
#  ('Amount', '('): 1,
#  ('Amount', ','): 1,
#  ('Amount', 'divided'): 4,
#  ('Amount', 'greater'): 1,
#  ('Amount', 'is'): 2,
#  ('Amount', 'may'): 1,
#  ('Amount', 'of'): 1,
#  ('Amount', 'to'): 1,
#  ('Amount', '”'): 4,
#  ('Amount.', 'The'): 1,
#  ('Amounts', 'or'): 4,
#  ('Anaxia', ','): 1,
#  ('Anaxia', 'Address'): 1,
#  ('Anaxia', 'By'): 1,
#  ('Any', 'notice'): 1,
#  ('Any', 'provision'): 1,
#  ('B', ')'): 3,
#  ('BE', 'OFFERED'): 1,
#  ('BEEN', 'REGISTERED'): 1,
#  ('Bob', 'Marley'): 2,
#  ('By', ':'): 2,
#  ('C', ')'): 1,
#  ('CEO', 'of'): 1,
#  ('CERTAIN', 'STATES.THESE'): 1,
#  ('CERTIFIES', 'THAT'): 1,
#  ('Cap', 'divided'): 2,
#  ('Cap', '”'): 2,
#  ('Capital', 'Stock'): 10,
#  ('Capital', 'Stock.'): 1,
#  ('Capitalization', '”'): 2,
#  ('Capitalization.', '“'): 2,
#  ('Cash-Out', 'Amount'): 3,
#  ('Cash-Out', 'Amounts'): 2,
#  ('Change', 'of'): 4,
#  ('Code', 'of'): 1,
#  ('Common', 'Stock'): 9,
#  ('Common', 'Stock.'): 1,
#  ('Company', '('): 2,
#  ('Company', ','): 5,
#  ('Company', ';'): 1,
#  ('Company', 'Capitalization'): 1,
#  ('Company', 'Capitalization.'): 1,
#  ('Company', 'Name'): 1,
#  ('Company', 'all'): 1,
#  ('Company', 'and'): 3,
#  ('Company', 'having'): 1,
#  ('Company', 'in'): 2,
#  ('Company', 'is'): 4,
#  ('Company', 'issues'): 1,
#  ('Company', 'may'): 3,
#  ('Company', 'of'): 2,
#  ('Company', 'or'): 3,
#  ('Company', 'outstanding'): 1,
#  ('Company', 'owns'): 1,
#  ('Company', 'pays'): 2,
#  ('Company', 'plan.'): 1,
#  ('Company', 'stockholder'): 1,
#  ('Company', 'stockholders'): 1,
#  ('Company', 'will'): 1,
#  ('Company', '’'): 10,
#  ('Company.', '('): 1,
#  ('Company.', '“'): 1,
#  ('Control', 'intended'): 1,
#  ('Control', 'or'): 1,
#  ('Control', 'to'): 1,
#  ('Control', '”'): 1,
#  ('Conversion', 'Amount'): 2,
#  ('Conversion', 'Amounts'): 2,
#  ('Converting', 'Securities'): 3,
#  ('D', 'under'): 1,
#  ('Discount', 'Rate'): 1,
#  ('Dissolution', 'Event'): 4,
#  ('Dissolution', 'Event.'): 2,
#  ('Dividend', 'Amount'): 2,
#  ('EFFECTIVE', 'REGISTRATION'): 1,
#  ('EXCEPT', 'AS'): 1,
#  ('EXEMPTION', 'THEREFROM.'): 1,
#  ('Email', ':'): 2,
#  ('Equity', ')'): 1,
#  ('Equity', 'Financing'): 9,
#  ('Equity', 'Financing.'): 3,
#  ('Event', ')'): 1,
#  ('Event', ','): 6,
#  ('Event', 'before'): 2,
#  ('Event', 'or'): 2,
#  ('Event', 'solely'): 1,
#  ('Event', '”'): 2,
#  ('Event.', '('): 1,
#  ('Event.', 'If'): 2,
#  ('Exchange', 'Act'): 2,
#  ('Excludes', ','): 1,
#  ('Excludes', 'the'): 1,
#  ('Financing', '('): 1,
#  ('Financing', ','): 4,
#  ('Financing', ';'): 1,
#  ('Financing', 'and'): 1,
#  ('Financing', 'before'): 1,
#  ('Financing', '”'): 1,
#  ('Financing.', 'If'): 1,
#  ('Financing.', '“'): 2,
#  ('Future', 'Equity'): 1,
#  ('Governing', 'Law'): 1,
#  ('HAVE', 'NOT'): 1,
#  ('HERETO', 'HAVE'): 1,
#  ('HYPOTHECATED', 'EXCEPT'): 1,
#  ('IN', 'THIS'): 1,
#  ('IN', 'WITNESS'): 1,
#  ('INSTRUMENT', 'AND'): 1,
#  ('INVESTOR', ':'): 1,
#  ('ISSUABLE', 'PURSUANT'): 1,
#  ('If', 'there'): 3,
#  ('In', 'a'): 1,
#  ('In', 'connection'): 1,
#  ('In', 'the'): 1,
#  ('Includes', 'all'): 6,
#  ('Includes', 'the'): 1,
#  ('Initial', 'Public'): 2,
#  ('Internal', 'Revenue'): 1,
#  ('Investor', ','): 6,
#  ('Investor', ';'): 1,
#  ('Investor', 'agree'): 1,
#  ('Investor', 'and'): 4,
#  ('Investor', 'at'): 1,
#  ('Investor', 'by'): 1,
#  ('Investor', 'has'): 4,
#  ('Investor', 'hereunder'): 1,
#  ('Investor', 'immediately'): 2,
#  ('Investor', 'in'): 1,
#  ('Investor', 'is'): 4,
#  ('Investor', 'may'): 1,
#  ('Investor', 'or'): 1,
#  ('Investor', 'pursuant'): 2,
#  ('Investor', 'the'): 1,
#  ('Investor', 'to'): 1,
#  ('Investor', 'under'): 1,
#  ('Investor', 'will'): 3,
#  ('Investor', 'would'): 1,
#  ('Investor', '’'): 4,
#  ('Investor', '”'): 1,
#  ('Investor.', '('): 1,
#  ('Junior', 'to'): 1,
#  ('Jurisdiction', ']'): 1,
#  ('LAWS', 'OF'): 1,
#  ('LAWS', 'PURSUANT'): 1,
#  ('Law', 'Jurisdiction'): 1,
#  ('Liquidation', 'Priority.'): 1,
#  ('Liquidity', 'Capitalization'): 1,
#  ('Liquidity', 'Capitalization.'): 1,
#  ('Liquidity', 'Event'): 10,
#  ('Liquidity', 'Event.'): 1,
#  ('Liquidity', 'Price'): 4,
#  ('MAY', 'NOT'): 1,
#  ('Majority-in-interest', '”'): 1,
#  ('Marley', '('): 1,
#  ('Marley', 'Title'): 1,
#  ('Minasoda', 'town'): 1,
#  ('NOT', 'BE'): 1,
#  ('NOT', 'BEEN'): 1,
#  ('Name', ':'): 1,
#  ('Name', ']'): 1,
#  ('Neither', 'this'): 1,
#  ('No', 'consents'): 1,
#  ('Notwithstanding', 'the'): 1,
#  ('OF', '1933'): 1,
#  ('OF', 'CERTAIN'): 1,
#  ('OFFERED', ','): 1,
#  ('OR', 'AN'): 1,
#  ('OR', 'HYPOTHECATED'): 1,
#  ('OR', 'OTHERWISE'): 1,
#  ('OR', 'UNDER'): 1,
#  ('OTHERWISE', 'TRANSFERRED'): 1,
#  ('Offering', '”'): 1,
#  ('Offering.', '“'): 1,
#  ('Old', 'Minasoda'): 1,
#  ('On', 'par'): 1,
#  ('Option', 'Pool'): 4,
#  ('Option', 'Pool.'): 1,
#  ('Options', '('): 1,
#  ('Options', ')'): 1,
#  ('Options', ';'): 2,
#  ('Options', 'and'): 2,
#  ('Options', 'in'): 1,
#  ('Options', 'or'): 1,
#  ('Options', 'that'): 2,
#  ('Options', '”'): 2,
#  ('PERMITTED', 'IN'): 1,
#  ('PLEDGED', 'OR'): 1,
#  ('PURSUANT', 'HERETO'): 1,
#  ('PURSUANT', 'TO'): 1,
#  ('Platinum', 'Address'): 1,
#  ('Pool', '('): 1,
#  ('Pool', ')'): 1,
#  ('Pool', ';'): 1,
#  ('Pool', '”'): 1,
#  ('Pool.', '“'): 1,
#  ('Post-Money', 'Valuation'): 4,
#  ('Preferred', 'Stock'): 18,
#  ('Preferred', 'Stock.'): 2,
#  ('Price', '('): 2,
#  ('Price', ')'): 1,
#  ('Price', ';'): 1,
#  ('Price', '”'): 2,
#  ('Price.', 'In'): 1,
#  ('Price.', '“'): 1,
#  ('Priority.', 'In'): 1,
#  ('Proceeds', ','): 2,
#  ('Proceeds', 'are'): 2,
#  ('Proceeds', 'equal'): 1,
#  ('Proceeds', 'on'): 1,
#  ('Proceeds', 'payable'): 2,
#  ('Proceeds', 'to'): 1,
#  ('Proceeds', 'will'): 1,
#  ('Proceeds', '”'): 1,
#  ('Promised', 'Options'): 6,
#  ('Psiayn', 'CEO'): 1,
#  ('Public', 'Offering'): 1,
#  ('Public', 'Offering.'): 1,
#  ('Purchase', 'Amount'): 9,
#  ('Purchase', 'Amount.'): 1,
#  ('REGISTERED', 'UNDER'): 1,
#  ('REGISTRATION', 'STATEMENT'): 1,
#  ('RSUs', ','): 1,
#  ('Rate', '”'): 1,
#  ('References', 'to'): 1,
#  ('Regulation', 'D'): 1,
#  ('Representations', '('): 2,
#  ('Revenue', 'Code'): 1,
#  ('Rule', '13d-3'): 1,
#  ('Rule', '501'): 1,
#  ('SAFE', '('): 1,
#  ('SAFE', 'AND'): 1,
#  ('SARs', ','): 1,
#  ('SECURITIES', 'ACT'): 2,
#  ('SECURITIES', 'ISSUABLE'): 1,
#  ('SECURITIES', 'LAWS'): 2,
#  ('SECURITIES', 'MAY'): 1,
#  ('SOLD', 'OR'): 1,
#  ('STATE', 'SECURITIES'): 1,
#  ('STATEMENT', 'OR'): 1,
#  ('STATES.THESE', 'SECURITIES'): 1,
#  ('Safe', '('): 1,
#  ('Safe', ')'): 1,
#  ('Safe', ','): 6,
#  ('Safe', 'Preferred'): 3,
#  ('Safe', 'Price'): 2,
#  ('Safe', 'Price.'): 2,
#  ('Safe', 'and'): 6,
#  ('Safe', 'and/or'): 1,
#  ('Safe', 'are'): 1,
#  ('Safe', 'be'): 1,
#  ('Safe', 'consistent'): 1,
#  ('Safe', 'constitutes'): 2,
#  ('Safe', 'do'): 1,
#  ('Safe', 'in'): 1,
#  ('Safe', 'into'): 1,
#  ('Safe', 'is'): 6,
#  ('Safe', 'may'): 1,
#  ('Safe', 'nor'): 1,
#  ('Safe', 'operate'): 1,
#  ('Safe', 'to'): 1,
#  ('Safe', 'under'): 1,
#  ('Safe', 'will'): 5,
#  ('Safe', '”'): 2,
#  ('SafePreferred', 'Stock'): 1,
#  ('Safes', ';'): 1,
#  ('Safes', 'and'): 1,
#  ('Safes', 'and/or'): 4,
#  ('Safes', 'have'): 1,
#  ('Safes', 'lacking'): 1,
#  ('Safes', 'must'): 1,
#  ('Safes', 'whose'): 1,
#  ('Safes', 'with'): 1,
#  ('Safes.', '('): 1,
#  ('Section', '1'): 4,
#  ('Section', '1.'): 1,
#  ('Section', '1.However'): 1,
#  ('Section', '13'): 1,
#  ('Section', '2for'): 1,
#  ('Sections', '304'): 1,
#  ('Securities', ','): 1,
#  ('Securities', ';'): 1,
#  ('Securities', 'Act'): 3,
#  ('Securities', 'Act.'): 1,
#  ('Securities', 'Exchange'): 2,
#  ('Securities', '”'): 1,
#  ('See', 'Section'): 1,
#  ('Senior', 'to'): 1,
#  ('Signature', 'page'): 1,
#  ('Simple', 'Agreement'): 1,
#  ('Standard', 'Preferred'): 7,
#  ('Star', 'Platinum'): 1,
#  ('State', 'of'): 1,
#  ('States', 'federal'): 2,
#  ('Stock', '('): 1,
#  ('Stock', ')'): 3,
#  ('Stock', ','): 8,
#  ('Stock', ';'): 1,
#  ('Stock', 'and'): 1,
#  ('Stock', 'at'): 1,
#  ('Stock', 'basis'): 1,
#  ('Stock', 'equal'): 3,
#  ('Stock', 'for'): 1,
#  ('Stock', 'if'): 1,
#  ('Stock', 'in'): 1,
#  ('Stock', 'issuable'): 1,
#  ('Stock', 'issued'): 4,
#  ('Stock', 'multiplied'): 1,
#  ('Stock', 'or'): 1,
#  ('Stock', 'pursuant'): 1,
#  ('Stock', 'that'): 1,
#  ('Stock', 'to'): 1,
#  ('Stock', 'who'): 1,
#  ('Stock', '’'): 1,
#  ('Stock', '”'): 4,
#  ('Stock.', 'The'): 2,
#  ('Stock.', '“'): 1,
#  ('Stock.', '”'): 1,
#  ('THAT', 'in'): 1,
#  ('THE', 'ACT'): 1,
#  ('THE', 'SECURITIES'): 2,
#  ('THE', '“'): 1,
#  ('THEREFROM.', '['): 1,
#  ('THIS', 'CERTIFIES'): 1,
#  ('THIS', 'INSTRUMENT'): 1,
#  ('THIS', 'SAFE'): 1,
#  ('TO', 'AN'): 1,
#  ('TRANSFERRED', ','): 1,
#  ('Termination.', 'This'): 1,
#  ('The', 'Company'): 1,
#  ('The', 'Investor'): 8,
#  ('The', 'execution'): 1,
#  ('The', 'parties'): 1,
#  ('The', 'performance'): 1,
#  ('The', '“'): 1,
#  ('This', 'Safe'): 4,
#  ('Title', ':'): 1,
#  ('To', 'its'): 2,
#  ('U.S.', 'federal'): 1,
#  ('U.S.', 'mail'): 1,
#  ('UNDER', 'THE'): 3,
#  ('Unissued', 'Option'): 5,
#  ('United', 'States'): 2,
#  ('Valuation', 'Cap'): 4,
#  ('WHEREOF', ','): 1,
#  ('WITNESS', 'WHEREOF'): 1,
#  ('[', 'Company'): 1,
#  ('[', 'Governing'): 1,
#  (']', ','): 1,
#  (']', 'SAFE'): 1,
#  ('a', ')'): 5,
#  ('a', 'Change'): 2,
#  ('a', 'Company'): 1,
#  ('a', 'Dissolution'): 1,
#  ('a', 'Liquidity'): 6,
#  ('a', 'bona'): 1,
#  ('a', 'choice'): 1,
#  ('a', 'complete'): 1,
#  ('a', 'corporation'): 1,
#  ('a', 'dividend'): 2,
#  ('a', 'fixed'): 1,
#  ('a', 'form'): 1,
#  ('a', 'future'): 1,
#  ('a', 'general'): 1,
#  ('a', 'holder'): 2,
#  ('a', 'legal'): 1,
#  ('a', 'majority'): 1,
#  ('a', 'material'): 1,
#  ('a', 'nominee'): 1,
#  ('a', 'party'): 2,
#  ('a', 'portion'): 2,
#  ('a', 'pre-money'): 1,
#  ('a', 'prior'): 1,
#  ('a', 'pro'): 1,
#  ('a', 'registration'): 1,
#  ('a', 'reincorporation'): 1,
#  ('a', 'result'): 1,
#  ('a', 'sale'): 1,
#  ('a', 'similar'): 1,
#  ('a', 'space'): 1,
#  ('a', 'tax-free'): 2,
#  ('a', 'total'): 1,
#  ('a', 'transaction'): 2,
#  ('a', 'view'): 1,
#  ('a', 'voluntary'): 1,
#  ('able', 'to'): 2,
#  ('about', '19-02-2022'): 1,
#  ('above', '('): 1,
#  ('acceleration', 'of'): 1,
#  ('accordance', 'with'): 2,
#  ('account', 'for'): 1,
#  ('accredited', 'investor'): 2,
#  ('acknowledge', 'and'): 1,
#  ('acknowledges', 'and'): 1,
#  ('acquired', 'by'): 1,
#  ('action', 'or'): 1,
#  ('actions', 'on'): 1,
#  ('actually', 'or'): 1,
#  ('additional', 'defined'): 1,
#  ('address', 'listed'): 2,
#  ('addressed', 'to'): 1,
#  ('adverse', 'effect'): 1,
#  ('advised', 'that'): 1,
#  ('affect', 'any'): 1,
#  ('affected', ','): 1,
#  ('affecting', 'the'): 2,
#  ('after', 'being'): 1,
#  ('after', 'such'): 1,
#  ('against', 'the'): 1,
#  ('agent', ','): 1,
#  ('agree', 'that'): 2,
#  ('agree', 'to'): 1,
#  ('agreements', 'or'): 1,
#  ('agrees', 'that'): 1,
#  ('all', '('): 2,
#  ('all', 'Converting'): 2,
#  ('all', 'United'): 1,
#  ('all', 'necessary'): 1,
#  ('all', 'of'): 3,
#  ('all', 'or'): 1,
#  ('all', 'patents'): 1,
#  ('all', 'securityholders'): 1,
#  ('all', 'shares'): 3,
#  ('all', 'such'): 2,
#  ('all', 'then-outstanding'): 1,
#  ('all', 'times'): 1,
#  ('also', 'receiving'): 1,
#  ('amended', ')'): 2,
#  ('amended', ','): 2,
#  ('amended.Accordingly', ','): 1,
#  ('amendment', ','): 1,
#  ('amount', 'determined'): 1,
#  ('amount', 'of'): 2,
#  ('amount', 'payable'): 1,
#  ('amounts', 'due'): 1,
#  ('an', 'Equity'): 3,
#  ('an', 'Initial'): 1,
#  ('an', 'accredited'): 2,
#  ('an', 'exemption'): 1,
#  ('an', 'indefinite'): 1,
#  ('an', 'instrument'): 1,
#  ('and', '('): 12,
#  ('and', ','): 1,
#  ('and', '1202'): 1,
#  ('and', '14'): 1,
#  ('and', 'Excludes'): 2,
#  ('and', 'Safes'): 1,
#  ('and', 'acknowledges'): 1,
#  ('and', 'agree'): 1,
#  ('and', 'agrees'): 1,
#  ('and', 'amount'): 1,
#  ('and', 'applicable'): 1,
#  ('and', 'as'): 1,
#  ('and', 'at'): 1,
#  ('and', 'authority'): 2,
#  ('and', 'binding'): 2,
#  ('and', 'bracketed'): 1,
#  ('and', 'business'): 1,
#  ('and', 'carry'): 1,
#  ('and', 'consummation'): 1,
#  ('and', 'content'): 1,
#  ('and', 'convertible'): 1,
#  ('and', 'creditor'): 1,
#  ('and', 'deliver'): 2,
#  ('and', 'delivered.'): 1,
#  ('and', 'each'): 1,
#  ('and', 'effect'): 1,
#  ('and', 'either'): 1,
#  ('and', 'experience'): 1,
#  ('and', 'general'): 2,
#  ('and', 'has'): 2,
#  ('and', 'if'): 1,
#  ('and', 'in'): 3,
#  ('and', 'indemnification'): 1,
#  ('and', 'is'): 1,
#  ('and', 'legally'): 1,
#  ('and', 'limited'): 1,
#  ('and', 'more'): 1,
#  ('and', 'not'): 2,
#  ('and', 'obligations'): 1,
#  ('and', 'on'): 1,
#  ('and', 'operate'): 1,
#  ('and', 'other'): 6,
#  ('and', 'outstanding'): 4,
#  ('and', 'payable'): 2,
#  ('and', 'performance'): 1,
#  ('and', 'provided'): 1,
#  ('and', 'restrictions'): 1,
#  ('and', 'return'): 1,
#  ('and', 'risks'): 1,
#  ('and', 'sells'): 1,
#  ('and', 'state'): 2,
#  ('and', 'such'): 2,
#  ('and', 'the'): 8,
#  ('and', 'to'): 1,
#  ('and', 'void'): 1,
#  ('and', 'warranties'): 1,
#  ('and', 'will'): 3,
#  ('and', '“'): 1,
#  ('and/or', 'Preferred'): 4,
#  ('and/or', 'its'): 1,
#  ('andprovided', ','): 1,
#  ('anti-dilution', 'protection'): 1,
#  ('any', 'Safes'): 1,
#  ('any', 'applicable'): 1,
#  ('any', 'conflict'): 1,
#  ('any', 'corporate'): 1,
#  ('any', 'date'): 1,
#  ('any', 'dividend'): 1,
#  ('any', 'drag-along'): 1,
#  ('any', 'equity'): 1,
#  ('any', 'general'): 1,
#  ('any', 'increases'): 1,
#  ('any', 'lien'): 1,
#  ('any', 'material'): 5,
#  ('any', 'matter'): 1,
#  ('any', 'obligations'): 1,
#  ('any', 'of'): 1,
#  ('any', 'one'): 2,
#  ('any', 'other'): 3,
#  ('any', 'outstanding'): 1,
#  ('any', 'participation'): 1,
#  ('any', 'property'): 1,
#  ('any', 'purpose'): 1,
#  ('any', 'qualifications'): 1,
#  ('any', 'reason'): 1,
#  ('any', 'reorganization'): 1,
#  ('any', 'requirement'): 1,
#  ('any', 'respect'): 1,
#  ('any', 'rights'): 1,
#  ('any', 'state'): 1,
#  ('any', 'such'): 1,
#  ('any', 'venture'): 1,
#  ('any', '“'): 1,
#  ('anything', 'in'): 1,
#  ('applicable', ','): 2,
#  ('applicable', 'Proceeds'): 2,
#  ('applicable', 'group'): 2,
#  ('applicable', 'laws.'): 1,
#  ('applicable', 'securities'): 1,
#  ('applicable', 'state'): 1,
#  ('applicable', 'to'): 5,
#  ('application', 'relating'): 2,
#  ('applied', 'in'): 1,
#  ('appropriate', 'variations'): 1,
#  ('approvals', ';'): 1,
#  ('approvals', 'are'): 1,
#  ('approvals', 'for'): 1,
#  ('are', 'Cash-Out'): 1,
#  ('are', 'also'): 1,
#  ('are', 'given'): 1,
#  ('are', 'insufficient'): 1,
#  ('are', 'not'): 1,
#  ('are', 'payable'): 1,
#  ('are', 'proceeds'): 1,
#  ('are', 'receiving'): 1,
#  ('are', 'registered'): 1,
#  ('are', 'required'): 1,
#  ('are', 'reserved'): 1,
#  ('are', 'the'): 2,
#  ('are', 'transferable'): 1,
#  ('arising', 'from'): 1,
#  ('as', 'a'): 6,
#  ('as', 'amended'): 2,
#  ('as', 'amended.Accordingly'): 1,
#  ('as', 'applicable'): 1,
#  ('as', 'certified'): 1,
#  ('as', 'common'): 1,
#  ('as', 'currently'): 1,
#  ('as', 'defined'): 1,
#  ('as', 'limited'): 2,
#  ('as', 'now'): 2,
#  ('as', 'of'): 2,
#  ('as', 'outstanding'): 1,
#  ('as', 'stock'): 1,
#  ('as', 'subsequently'): 1,
#  ('as', 'such'): 2,
#  ('as', 'the'): 1,
#  ('as', 'this'): 1,
#  ('as', 'to'): 1,
#  ('as-converted', 'to'): 1,
#  ('as-converted', '”'): 1,
#  ('aside', 'for'): 1,
#  ('asset', 'or'): 1,
#  ('assets', '('): 1,
#  ('assets', 'of'): 1,
#  ('assign', 'this'): 1,
#  ('assignable', ','): 1,
#  ('assigned', 'without'): 1,
#  ('assignment', 'for'): 1,
#  ('at', 'a'): 1,
#  ('at', 'all'): 1,
#  ('at', 'http'): 1,
#  ('at', 'least'): 1,
#  ('at', 'such'): 1,
#  ('at', 'the'): 2,
#  ('authority', 'to'): 2,
#  ('authorization', 'applicable'): 1,
#  ('authorization', 'of'): 1,
#  ('authorized', 'by'): 1,
#  ('automatic', 'conversion'): 2,
#  ('automatically', 'be'): 2,
#  ('automatically', 'convert'): 1,
#  ('automatically', 'terminate'): 1,
#  ('available', 'at'): 1,
#  ('available', 'for'): 2,
#  ('available.', 'The'): 1,
#  ('awards', 'or'): 1,
#  ('b', ')'): 5,
#  ('bankruptcy', ','): 2,
#  ('based', 'on'): 1,
#  ('basis', ','): 1,
#  ('basis', 'for'): 1,
#  ('basis', 'to'): 1,
#  ('be', 'acquired'): 1,
#  ('be', 'affected'): 1,
#  ('be', 'amended'): 2,
#  ('be', 'assigned'): 1,
#  ('be', 'based'): 1,
#  ('be', 'characterized'): 1,
#  ('be', 'conducted'): 1,
#  ('be', 'considered'): 1,
#  ('be', 'construed'): 1,
#  ('be', 'deemed'): 3,
#  ('be', 'distributed'): 1,
#  ('be', 'due'): 1,
#  ('be', 'duly'): 1,
#  ('be', 'entered'): 1,
#  ('be', 'entitled'): 2,
#  ('be', 'expected'): 1,
#  ('be', 'given'): 1,
#  ('be', 'governed'): 1,
#  ('be', 'ineligible'): 1,
#  ('be', 'invalid'): 1,
#  ('be', 'notified'): 1,
#  ('be', 'received'): 1,
#  ('be', 'resold'): 1,
#  ('be', 'solicited'): 1,
#  ('be', 'the'): 1,
#  ('bear', 'the'): 1,
#  ('becomes', 'the'): 1,
#  ('been', ','): 1,
#  ('been', 'advised'): 1,
#  ('been', 'duly'): 1,
#  ('been', 'issued'): 1,
#  ('been', 'registered'): 1,
#  ('before', 'the'): 3,
#  ('being', 'deposited'): 1,
#  ('below.', 'This'): 1,
#  ('beneficial', 'owner'): 1,
#  ('benefit', 'of'): 1,
#  ('binding', 'obligation'): 2,
#  ('blanks', 'and'): 1,
#  ('blue', 'Name'): 1,
#  ('board', 'of'): 2,
#  ('bona', 'fide'): 1,
#  ('both', 'of'): 1,
#  ('bound', ','): 1,
#  ('bound', ';'): 1,
#  ('bracketed', 'terms.'): 1,
#  ('breach', 'of'): 1,
#  ('business', 'as'): 2,
#  ('business', 'matters'): 1,
#  ('business', 'operations.'): 1,
#  ('business', 'or'): 1,
#  ('but', 'in'): 1,
#  ('but', 'not'): 2,
#  ('but', 'ungranted'): 1,
#  ('by', '('): 2,
#  ('by', 'Bob'): 1,
#  ('by', 'all'): 1,
#  ('by', 'bankruptcy'): 2,
#  ('by', 'either'): 1,
#  ('by', 'email'): 1,
#  ('by', 'investors'): 1,
#  ('by', 'its'): 1,
#  ('by', 'one'): 1,
#  ('by', 'operation'): 1,
#  ('by', 'or'): 1,
#  ('by', 'overnight'): 1,
#  ('by', 'the'): 11,
#  ('by', 'this'): 2,
#  ('by', 'which'): 2,
#  ('by', 'written'): 2,
#  ('bylaws', ','): 1,
#  ('bythe', 'Liquidity'): 1,
#  ('c', ')'): 4,
#  ('calculated', 'as'): 2,
#  ('calculating', 'such'): 1,
#  ('calculation', 'of'): 1,
#  ('can', 'not'): 1,
#  ('can', 'obtain'): 1,
#  ('capable', 'of'): 1,
#  ('capacity', ','): 1,
#  ('capital', ','): 1,
#  ('capital', 'fund'): 1,
#  ('capital', 'stock'): 1,
#  ('carry', 'on'): 1,
#  ('case', ','): 2,
#  ('case', 'of'): 1,
#  ('cash', 'and'): 1,
#  ('cash', 'portion'): 1,
#  ('caused', 'this'): 1,
#  ('certain', 'additional'): 1,
#  ('certain', 'shares'): 1,
#  ('certificate', 'of'): 1,
#  ('certified', 'or'): 1,
#  ('change', 'the'): 1,
#  ('characterized', 'as'): 1,
#  ('choice', ','): 1,
#  ('choice', 'as'): 1,
#  ('choose', 'to'): 1,
#  ('claims', ','): 1,
#  ('claims', 'for'): 1,
#  ('clause', '('): 1,
#  ('clauses', '('): 1,
#  ('closing', 'of'): 4,
#  ('commercially', 'reasonable'): 1,
#  ('commitment', 'underwritten'): 1,
#  ('common', 'control'): 1,
#  ('common', 'stock'): 1,
#  ('company', 'with'): 1,
#  ('complete', 'loss'): 1,
#  ('concurrent', 'with'): 1,
#  ('condition', 'and'): 1,
#  ('conducted', ','): 1,
#  ('conducted', 'and'): 1,
#  ('conducted.', '('): 1,
#  ('confer', 'on'): 1,
#  ('conflict', 'with'): 1,
#  ('conflicts', 'of'): 1,
#  ('connection', 'with'): 8,
#  ('consent', 'by'): 1,
#  ('consent', 'of'): 4,
#  ('consent', 'to'): 1,
#  ('consents', 'or'): 1,
#  ('consideration', ')'): 1,
#  ('consideration', 'that'): 1,
#  ('considered', 'to'): 1,
#  ('consistent', 'with'): 1,
#  ('consolidation', 'of'): 1,
#  ('constitutes', 'a'): 1,
#  ('constitutes', 'valid'): 1,
#  ('construed', 'to'): 1,
#  ('consummation', 'of'): 3,
#  ('containing', 'a'): 1,
#  ('contemplated', 'by'): 1,
#  ('content', 'to'): 1,
#  ('contract', 'to'): 2,
#  ('contractual', 'claims'): 1,
#  ('control', 'with'): 1,
#  ('controlled', 'by'): 2,
#  ('controls', ','): 1,
#  ('conversion', 'of'): 2,
#  ('conversion', 'price'): 1,
#  ('convert', 'into'): 2,
#  ('converted', 'into'): 1,
#  ('convertible', 'debt'): 1,
#  ('convertible', 'promissory'): 3,
#  ('convertible', 'securities'): 3,
#  ('copyrights', ','): 1,
#  ('corporate', 'action'): 1,
#  ('corporate', 'approvals'): 2,
#  ('corporation', 'duly'): 1,
#  ('corporation', 'tesla'): 1,
#  ('could', 'reasonably'): 1,
#  ('counting', ')'): 1,
#  ('courier', 'or'): 1,
#  ('cover', 'Promised'): 1,
#  ('creation', 'or'): 1,
#  ('creditor', 'claims'): 1,
#  ('creditors', 'or'): 1,
#  ('creditors', '’'): 2,
#  ('current', 'certificate'): 1,
#  ('currently', 'proposed'): 1,
#  ('customary', 'exceptions'): 1,
#  ('d', ')'): 7,
#  ('date', 'as'): 1,
#  ('date', 'on'): 1,
#  ('debt', 'instruments'): 1,
#  ('debt', 'or'): 2,
#  ('deemed', 'a'): 1,
#  ('deemed', 'null'): 1,
#  ('deemed', 'sufficient'): 1,
#  ('default', ','): 1,
#  ('defaults', ','): 1,
#  ('defined', 'in'): 2,
#  ('defined', 'terms.'): 1,
#  ('deliver', 'this'): 1,
#  ('deliver', 'to'): 1,
#  ('delivered', 'personally'): 1,
#  ('delivered.', 'Anaxia'): 1,
#  ('delivery', 'and'): 1,
#  ('deposited', 'in'): 1,
#  ('described', 'below.'): 1,
#  ('described', 'in'): 2,
#  ('determined', 'by'): 1,
#  ('dio', '@'): 1,
#  ('directly', 'or'): 2,
#  ('director', 'of'): 1,
#  ('directors', ','): 1,
#  ('directors', 'in'): 1,
#  ('directors', 'or'): 1,
#  ('disposition', 'of'): 1,
#  ('dissolution', 'or'): 1,
#  ('distributed', 'pro'): 1,
#  ('distributing', 'the'): 1,
#  ('distribution', 'thereof'): 1,
#  ('distribution.', '“'): 1,
#  ('disturbed', 'thereby.'): 1,
#  ('divided', 'by'): 5,
#  ('divided', 'bythe'): 1,
#  ('dividend', 'date'): 1,
#  ('dividend', 'on'): 2,
#  ('dividend', 'rights'): 1,
#  ('dividend', 'that'): 1,
#  ('do', 'not'): 1,
#  ('documents', 'are'): 1,
#  ('documents', 'have'): 1,
#  ('documents', 'related'): 1,
#  ('documents', 'to'): 1,
#  ('does', 'not'): 1,
#  ('domicile.', '('): 1,
#  ('double-', 'counting'): 1,
#  ('double-counting', ')'): 1,
#  ('drag-along', 'applicable'): 1,
#  ('due', ';'): 1,
#  ('due', 'and'): 2,
#  ('due', 'the'): 1,
#  ('duly', 'authorized'): 1,
#  ('duly', 'executed'): 1,
#  ('duly', 'organized'): 1,
#  ('e', ')'): 3,
#  ('each', 'case'): 1,
#  ('each', 'holder'): 1,
#  ('earliest', 'to'): 1,
#  ('economic', 'risk'): 1,
#  ('effect', 'and'): 1,
#  ('effect', 'on'): 1,
#  ('either', '('): 1,
#  ('either', 'party'): 1,
#  ('election', 'of'): 2,
#  ('email', 'to'): 1,
#  ('enforceable', 'against'): 1,
#  ('enforceable', 'in'): 1,
#  ('enforcement', 'of'): 2,
#  ('entered', 'into'): 1,
#  ('entitled', ','): 1,
#  ('entitled', 'to'): 2,
#  ('entity', 'or'): 1,
#  ('entity', 'who'): 1,
#  ('equal', 'priority'): 1,
#  ('equal', 'the'): 1,
#  ('equal', 'to'): 7,
#  ('equity', 'incentive'): 1,
#  ('equity.', '('): 1,
#  ('equity.', 'To'): 1,
#  ('evaluating', 'the'): 1,
#  ('even', 'if'): 1,
#  ('event', ','): 1,
#  ('event', 'any'): 1,
#  ('event', 'that'): 1,
#  ('exceed', 'the'): 1,
#  ('except', 'as'): 2,
#  ('except', 'to'): 2,
#  ('exceptions', 'to'): 1,
#  ('exchange', 'for'): 1,
#  ('excluding', 'a'): 1,
#  ('execute', 'and'): 2,
#  ('executed', 'and'): 1,
#  ('execution', ','): 1,
#  ('execution', 'of'): 1,
#  ('exemption', 'from'): 1,
#  ('existing', 'and'): 1,
#  ('existing', 'which'): 1,
#  ('expected', 'to'): 1,
#  ('experience', 'in'): 1,
#  ('extent', 'Proceeds'): 1,
#  ('extent', 'necessary'): 1,
#  ('extent', 'receiving'): 1,
#  ('extent', 'such'): 2,
#  ('f', ')'): 1,
#  ('failure', 'to'): 1,
#  ('faith', 'for'): 1,
#  ('federal', 'and'): 2,
#  ('federal', 'income'): 1,
#  ('fide', 'transaction'): 1,
#  ('filed', 'under'): 1,
#  ('filings', 'under'): 1,
#  ('fill', 'in'): 1,
#  ('financial', 'and'): 1,
#  ('financial', 'condition'): 1,
#  ('firm', 'commitment'): 1,
#  ('first', 'firm'): 1,
#  ('fixed', 'valuation'): 1,
#  ('following', 'the'): 1,
#  ('follows', ')'): 1,
#  ('for', 'Common'): 2,
#  ('for', 'Future'): 1,
#  ('for', 'U.S.'): 1,
#  ('for', 'United'): 1,
#  ('for', 'all'): 1,
#  ('for', 'an'): 1,
#  ('for', 'any'): 3,
#  ('for', 'distribution.'): 1,
#  ('for', 'future'): 1,
#  ('for', 'investment'): 1,
#  ('for', 'its'): 2,
#  ('for', 'other'): 1,
#  ('for', 'payment'): 2,
#  ('for', 'purposes'): 3,
#  ('for', 'resale'): 1,
#  ('for', 'such'): 1,
#  ('for', 'the'): 8,
#  ('force', 'and'): 1,
#  ('foregoing', ','): 2,
#  ('foregoing', 'intent'): 1,
#  ('forfeiture', ','): 1,
#  ('form', ','): 1,
#  ('form', 'and'): 2,
#  ('form', 'of'): 1,
#  ('forms', 'available'): 1,
#  ('from', 'a'): 1,
#  ('from', 'such'): 1,
#  ('from', 'the'): 1,
#  ('full', 'force'): 1,
#  ('full', 'legal'): 1,
#  ('full', 'payments'): 2,
#  ('fund', 'now'): 1,
#  ('funding', 'the'): 1,
#  ('further', ','): 2,
#  ('future', 'grant'): 1,
#  ('future', 'right'): 1,
#  ('g', ')'): 1,
#  ('general', 'application'): 2,
#  ('general', 'assignment'): 1,
#  ('general', 'partner'): 1,
#  ('general', 'partners'): 1,
#  ('general', 'principles'): 2,
#  ('generally', 'and'): 2,
#  ('generally', 'applicable'): 1,
#  ('give', 'or'): 1,
#  ('given', 'a'): 1,
#  ('given', 'the'): 1,
#  ('good', 'faith'): 1,
#  ('good', 'standing'): 1,
#  ('governed', 'by'): 1,
#  ('grant', 'and'): 1,
#  ('granting', 'any'): 1,
#  ('greater', 'of'): 3,
#  ('greater', 'than'): 1,
#  ('group', 'of'): 2,
#  ('group', '”'): 1,
#  ('has', 'been'): 3,
#  ('has', 'full'): 1,
#  ('has', 'modified'): 1,
#  ('has', 'no'): 1,
#  ('has', 'such'): 1,
#  ('has', 'the'): 1,
#  ('have', 'a'): 2,
#  ('have', 'been'): 1,
#  ('have', 'caused'): 1,
#  ('have', 'customary'): 1,
#  ('have', 'equal'): 1,
#  ('have', 'not'): 1,
#  ('have', 'the'): 1,
#  ('having', 'the'): 2,
#  ('held', 'to'): 1,
#  ('hereafter', 'existing'): 1,
#  ('hereunder', 'for'): 1,
#  ('hereunder', 'will'): 1,
#  ('hereunder.', 'This'): 1,
#  ('holder', 'of'): 3,
#  ('holders', 'in'): 1,
#  ('holders', 'of'): 3,
#  ('hours', 'after'): 1,
#  ('however', ','): 1,
#  ('http', ':'): 1,
#  ('i', ')'): 15,
#  ('identical', 'rights'): 1,
#  ('if', 'applicable'): 1,
#  ('if', 'not'): 2,
#  ('if', 'the'): 2,
#  ('if', 'there'): 1,
#  ('ii', ')'): 16,
#  ('iii', ')'): 7,
#  ('illegal', 'or'): 1,
#  ('immediately', 'after'): 1,
#  ('immediately', 'following'): 1,
#  ('immediately', 'prior'): 5,
#  ('impairing', 'the'): 1,
#  ('imposition', 'of'): 1,
#  ('in', ','): 1,
#  ('in', 'Rule'): 2,
#  ('in', 'Section'): 1,
#  ('in', 'a'): 1,
#  ('in', 'accordance'): 2,
#  ('in', 'an'): 1,
#  ('in', 'any'): 2,
#  ('in', 'blanks'): 1,
#  ('in', 'clauses'): 1,
#  ('in', 'connection'): 7,
#  ('in', 'each'): 1,
#  ('in', 'exchange'): 1,
#  ('in', 'financial'): 1,
#  ('in', 'form'): 1,
#  ('in', 'full'): 1,
#  ('in', 'good'): 2,
#  ('in', 'lieu'): 1,
#  ('in', 'part'): 1,
#  ('in', 'proportion'): 1,
#  ('in', 'shares'): 1,
#  ('in', 'the'): 10,
#  ('in', 'this'): 3,
#  ('in', 'violation'): 1,
#  ('in', 'which'): 2,
#  ('in', 'whole'): 2,
#  ('incentive', 'or'): 1,
#  ('includes', 'options'): 1,
#  ('includes', 'this'): 1,
#  ('including', ','): 4,
#  ('including', 'but'): 2,
#  ('including', 'contractual'): 1,
#  ('including', 'without'): 2,
#  ('income', 'tax'): 3,
#  ('incorporation', ','): 1,
#  ('incorporation', 'or'): 1,
#  ('increases', 'to'): 1,
#  ('incur', 'a'): 1,
#  ('indebtedness', 'and'): 1,
#  ('indefinite', 'period'): 1,
#  ('indemnification', 'obligations'): 1,
#  ('indirectly', ','): 2,
#  ('individually', ','): 1,
#  ('ineligible', 'to'): 1,
#  ('information', ','): 1,
#  ('informational', 'statements'): 1,
#  ('infringement', 'of'): 1,
#  ('initial', 'closing'): 3,
#  ('initial', 'conversion'): 1,
#  ('initial', 'public'): 1,
#  ('insolvency', 'or'): 2,
#  ('instrument', ','): 1,
#  ('instrument', 'containing'): 1,
#  ('instrument.', '“'): 1,
#  ('instruments', ';'): 1,
#  ('insufficient', 'to'): 1,
#  ('intellectual', 'property'): 1,
#  ('intended', 'to'): 3,
#  ('intent', 'for'): 1,
#  ('intention', 'of'): 1,
#  ('into', 'Capital'): 1,
#  ('into', 'shares'): 2,
#  ('into', 'the'): 1,
#  ('into', 'with'): 1,
#  ('invalid', ','): 1,
#  ('invalidate', 'this'): 1,
#  ('investing', 'new'): 1,
#  ('investment', ','): 2,
#  ('investment', 'for'): 1,
#  ('investment', 'without'): 1,
#  ('investor', 'as'): 1,
#  ('investor', 'at'): 1,
#  ('investors', 'for'): 1,
#  ('investors', 'investing'): 1,
#  ('involuntary.', '“'): 1,
#  ('is', '$'): 1,
#  ('is', '('): 1,
#  ('is', ','): 1,
#  ('is', ':'): 1,
#  ('is', 'a'): 5,
#  ('is', 'able'): 2,
#  ('is', 'an'): 2,
#  ('is', 'applied'): 1,
#  ('is', 'available.'): 1,
#  ('is', 'bound'): 2,
#  ('is', 'calculated'): 2,
#  ('is', 'capable'): 1,
#  ('is', 'controlled'): 2,
#  ('is', 'defined'): 1,
#  ('is', 'for'): 1,
#  ('is', 'intended'): 1,
#  ('is', 'no'): 1,
#  ('is', 'not'): 3,
#  ('is', 'one'): 1,
#  ('is', 'outstanding'): 1,
#  ('is', 'paid'): 1,
#  ('is', 'purchasing'): 1,
#  ('is', 'under'): 1,
#  ('is', 'within'): 1,
#  ('issuable', 'pursuant'): 1,
#  ('issuance', 'of'): 1,
#  ('issued', 'and'): 4,
#  ('issued', 'by'): 1,
#  ('issued', 'on'): 1,
#  ('issued', 'to'): 2,
#  ('issues', 'and'): 1,
#  ('issues', 'to'): 1,
#  ('it', 'is'): 2,
#  ('its', 'Cash-Out'): 1,
#  ('its', 'Conversion'): 1,
#  ('its', 'board'): 1,
#  ('its', 'business'): 3,
#  ('its', 'current'): 1,
#  ('its', 'knowledge'): 2,
#  ('its', 'obligations'): 1,
#  ('its', 'outstanding'): 1,
#  ('its', 'own'): 1,
#  ('its', 'properties'): 1,
#  ('its', 'rights'): 1,
#  ('its', 'state'): 1,
#  ('its', 'terms'): 2,
#  ('judgment', ','): 1,
#  ('junior', 'to'): 1,
#  ('jurisdiction.', '('): 1,
#  ('knowledge', ','): 2,
#  ('knowledge', 'and'): 1,
#  ('lacking', 'one'): 1,
#  ('latter', 'case'): 1,
#  ('law', 'or'): 1,
#  ('law', 'provisions'): 1,
#  ('laws', ';'): 1,
#  ('laws', 'and'): 1,
#  ('laws', 'of'): 4,
#  ('laws', 'or'): 1,
#  ('laws.', 'Notwithstanding'): 1,
#  ('lease', 'and'): 1,
#  ('lease', 'or'): 1,
#  ('least', 'a'): 1,
#  ('legal', ','): 1,
#  ('legal', 'capacity'): 1,
#  ('legal', 'rights'): 1,
#  ('legally', 'available'): 1,
#  ('liability', 'and'): 1,
#  ('license', 'or'): 1,
#  ('licenses', ','): 1,
#  ('lien', 'on'): 1,
#  ('lieu', 'of'): 1,
#  ('like', 'standard'): 1,
#  ('limitation', ','): 4,
#  ('limitation', 'generally'): 1,
#  ('limitation', 'shares'): 1,
#  ('limitation', 'stock'): 1,
#  ('limited', 'by'): 2,
#  ('limited', 'liability'): 1,
#  ('limited', 'representations'): 1,
#  ('limited', 'to'): 2,
#  ('liquidation', ','): 1,
#  ('liquidation', 'preference'): 2,
#  ('liquidation', 'preferences'): 1,
#  ('listed', 'on'): 2,
#  ('loss', 'of'): 1,
#  ('lowest', 'price'): 1,
#  ('made', 'prior'): 1,
#  ('mail', 'as'): 1,
#  ('mail', 'with'): 1,
#  ('majority', 'of'): 1,
#  ('majority-in-interest', 'of'): 1,
#  ('management', 'company'): 1,
#  ('managing', 'member'): 1,
#  ('managing', 'members'): 1,
#  ('manner', ','): 1,
#  ('manner', 'and'): 1,
#  ('manner.', '“'): 1,
#  ('marks', ','): 1,
#  ('material', 'adverse'): 1,
#  ('material', 'debt'): 2,
#  ('material', 'judgment'): 1,
#  ('material', 'permit'): 1,
#  ('material', 'statute'): 1,
#  ('matter', 'submitted'): 1,
#  ('matters', 'that'): 1,
#  ('may', 'assign'): 1,
#  ('may', 'be'): 2,
#  ('may', 'not'): 2,
#  ('may', 'reduce'): 1,
#  ('may', 'void'): 1,
#  ('mean', 'this'): 1,
#  ('meaning', 'of'): 1,
#  ('means', '('): 2,
#  ('means', ','): 1,
#  ('means', 'a'): 2,
#  ('means', 'all'): 1,
#  ('means', 'an'): 1,
#  ('means', 'cash'): 1,
#  ('means', 'promised'): 1,
#  ('means', 'the'): 6,
#  ('meetings', ','): 1,
#  ('member', ','): 1,
#  ('members', 'of'): 2,
#  ('merger', 'or'): 1,
#  ('merits', 'and'): 1,
#  ('modification', 'treats'): 1,
#  ('modified', 'by'): 2,
#  ('modified', 'in'): 1,
#  ('modified', 'the'): 1,
#  ('money', 'in'): 1,
#  ('more', 'general'): 1,
#  ('more', 'of'): 2,
#  ('more', 'particularly'): 1,
#  ('more', 'than'): 1,
#  ('multiplied', 'by'): 1,
#  ('must', 'be'): 1,
#  ('names', ','): 1,
#  ('necessary', 'actions'): 1,
#  ('necessary', 'corporate'): 1,
#  ('necessary', 'for'): 1,
#  ('necessary', 'to'): 1,
#  ('neither', 'one'): 1,
#  ('new', 'money'): 1,
#  ('no', 'present'): 1,
#  ('no', 'term'): 1,
#  ('nominee', 'or'): 1,
#  ('non-compliance', 'with'): 1,
#  ('non-participating', 'Preferred'): 1,
#  ('nonrenewal', 'of'): 1,
#  ('nor', 'the'): 1,
#  ('nor', 'will'): 1,
#  ('not', ':'): 1,
#  ('not', 'actually'): 1,
#  ('not', 'affect'): 1,
#  ('not', 'an'): 1,
#  ('not', 'and'): 1,
#  ('not', 'as'): 1,
#  ('not', 'be'): 3,
#  ('not', 'been'): 1,
#  ('not', 'choose'): 1,
#  ('not', 'entitled'): 1,
#  ('not', 'in'): 1,
#  ('not', 'limited'): 2,
#  ('not', 'obtained'): 1,
#  ('not', 'payable'): 1,
#  ('not', 'reduce'): 1,
#  ('not', 'subject'): 1,
#  ('not', 'with'): 1,
#  ('notes', '('): 1,
#  ('notes', 'and'): 1,
#  ('notes', 'are'): 1,
#  ('notice', 'of'): 1,
#  ('notice', 'required'): 1,
#  ('notice.', '('): 1,
#  ('notified', 'at'): 1,
#  ('notionally', 'converted'): 1,
#  ('notwithstanding', 'the'): 1,
#  ('now', 'conducted'): 1,
#  ('now', 'conducted.'): 1,
#  ('now', 'or'): 1,
#  ('null', 'and'): 1,
#  ('number', 'of'): 3,
#  ('obligation', 'of'): 2,
#  ('obligations', 'arising'): 1,
#  ('obligations', 'hereunder'): 1,
#  ('obligations', 'hereunder.'): 1,
#  ('obligations', 'on'): 1,
#  ('obtain', 'on'): 1,
#  ('obtained', ')'): 1,
#  ('occur', 'of'): 1,
#  ('of', '$'): 1,
#  ('of', '('): 2,
#  ('of', ','): 3,
#  ('of', '1934'): 2,
#  ('of', '1986'): 1,
#  ('of', ':'): 2,
#  ('of', 'Anaxia'): 1,
#  ('of', 'Capital'): 8,
#  ('of', 'Common'): 5,
#  ('of', 'Control'): 4,
#  ('of', 'Conversion'): 1,
#  ('of', 'Preferred'): 3,
#  ('of', 'Proceeds'): 4,
#  ('of', 'Regulation'): 1,
#  ('of', 'Safe'): 1,
#  ('of', 'Safes'): 1,
#  ('of', 'Safes.'): 1,
#  ('of', 'Section'): 1,
#  ('of', 'Sections'): 1,
#  ('of', 'Standard'): 4,
#  ('of', '['): 1,
#  ('of', 'a'): 2,
#  ('of', 'all'): 3,
#  ('of', 'amounts'): 1,
#  ('of', 'an'): 1,
#  ('of', 'any'): 4,
#  ('of', 'calculating'): 1,
#  ('of', 'consideration'): 1,
#  ('of', 'creditors'): 2,
#  ('of', 'directors'): 3,
#  ('of', 'equity.'): 2,
#  ('of', 'evaluating'): 1,
#  ('of', 'funding'): 1,
#  ('of', 'general'): 2,
#  ('of', 'immediately'): 2,
#  ('of', 'incorporation'): 2,
#  ('of', 'its'): 1,
#  ('of', 'law'): 2,
#  ('of', 'meetings'): 1,
#  ('of', 'members'): 1,
#  ('of', 'more'): 1,
#  ('of', 'operations'): 1,
#  ('of', 'or'): 1,
#  ('of', 'outstanding'): 1,
#  ('of', 'price-based'): 1,
#  ('of', 'raising'): 1,
#  ('of', 'related'): 4,
#  ('of', 'selling'): 1,
#  ('of', 'shares'): 3,
#  ('of', 'such'): 11,
#  ('of', 'the'): 46,
#  ('of', 'this'): 13,
#  ('of', 'those'): 1,
#  ('of', 'time.'): 1,
#  ('of', 'transactions'): 1,
#  ('offering', 'of'): 1,
#  ('officer', 'or'): 1,
#  ('on', 'a'): 2,
#  ('on', 'any'): 2,
#  ('on', 'commercially'): 1,
#  ('on', 'its'): 2,
#  ('on', 'or'): 1,
#  ('on', 'outstanding'): 1,
#  ('on', 'par'): 1,
#  ('on', 'such'): 1,
#  ('on', 'the'): 10,
#  ('on', 'their'): 1,
#  ('on', 'which'): 1,
#  ('one', 'has'): 1,
#  ('one', 'of'): 1,
#  ('one', 'or'): 4,
#  ('only', 'to'): 1,
#  ('only', 'will'): 1,
#  ('operate', 'its'): 1,
#  ('operate', 'like'): 1,
#  ('operate', 'or'): 1,
#  ('operate', 'to'): 1,
#  ('operation', 'of'): 1,
#  ('operations', ','): 1,
#  ('operations.', '('): 1,
#  ('operations.', 'References'): 1,
#  ('operative', 'and'): 1,
#  ('options', ','): 1,
#  ('or', '('): 9,
#  ('or', '48'): 1,
#  ('or', 'Dissolution'): 1,
#  ('or', 'Proceeds'): 1,
#  ('or', 'Promised'): 1,
#  ('or', 'Safe'): 1,
#  ('or', 'Section'): 1,
#  ('or', 'about'): 1,
#  ('or', 'affecting'): 2,
#  ('or', 'agent'): 1,
#  ('or', 'an'): 1,
#  ('or', 'any'): 2,
#  ('or', 'approvals'): 1,
#  ('or', 'assignable'): 1,
#  ('or', 'authorization'): 1,
#  ('or', 'be'): 1,
#  ('or', 'both'): 1,
#  ('or', 'by'): 3,
#  ('or', 'bylaws'): 1,
#  ('or', 'can'): 1,
#  ('or', 'concurrent'): 1,
#  ('or', 'consolidation'): 1,
#  ('or', 'contract'): 2,
#  ('or', 'default'): 1,
#  ('or', 'defaults'): 1,
#  ('or', 'director'): 1,
#  ('or', 'disturbed'): 1,
#  ('or', 'filings'): 1,
#  ('or', 'for'): 1,
#  ('or', 'hereafter'): 1,
#  ('or', 'imposition'): 1,
#  ('or', 'in'): 4,
#  ('or', 'indirectly'): 2,
#  ('or', 'infringement'): 1,
#  ('or', 'involuntary.'): 1,
#  ('or', 'is'): 1,
#  ('or', 'limitation'): 1,
#  ('or', 'managing'): 1,
#  ('or', 'modification'): 1,
#  ('or', 'modified'): 2,
#  ('or', 'more'): 3,
#  ('or', 'non-compliance'): 1,
#  ('or', 'nonrenewal'): 1,
#  ('or', 'notionally'): 1,
#  ('or', 'on'): 1,
#  ('or', 'operations.'): 1,
#  ('or', 'other'): 4,
#  ('or', 'otherwise'): 2,
#  ('or', 'permitted'): 1,
#  ('or', 'possesses'): 1,
#  ('or', 'post-money'): 1,
#  ('or', 'purchases'): 1,
#  ('or', 'registered'): 1,
#  ('or', 'regulation'): 2,
#  ('or', 'resulting'): 1,
#  ('or', 'revenue'): 1,
#  ('or', 'rights'): 1,
#  ('or', 'sent'): 1,
#  ('or', 'series'): 5,
#  ('or', 'setting'): 1,
#  ('or', 'shares'): 1,
#  ('or', 'similar'): 5,
#  ('or', 'substantially'): 1,
#  ('or', 'such'): 1,
#  ('or', 'the'): 3,
#  ('or', 'to'): 2,
#  ('or', 'together'): 1,
#  ('or', 'under'): 1,
#  ('or', 'understandings'): 1,
#  ('or', 'unenforceable'): 1,
#  ('or', 'unless'): 1,
#  ('or', 'unvested.'): 1,
#  ('or', 'winding'): 1,
#  ('or', 'withhold'): 1,
#  ('or', 'would'): 1,
#  ('or', '“'): 1,
#  ('organized', ','): 1,
#  ('other', ';'): 1,
#  ('other', 'Safes'): 5,
#  ('other', 'assets'): 1,
#  ('other', 'convertible'): 3,
#  ('other', 'disposition'): 1,
#  ('other', 'entity'): 1,
#  ('other', 'informational'): 1,
#  ('other', 'intellectual'): 1,
#  ('other', 'laws'): 2,
#  ('other', 'liquidation'): 1,
#  ('other', 'provision'): 1,
#  ('other', 'surviving'): 1,
#  ('other', 'than'): 5,
#  ('others.', '4.Investor'): 1,
#  ('otherwise', ','): 1,
#  ('otherwise', 'be'): 1,
#  ('otherwise', 'distributing'): 1,
#  ('outstanding', ','): 1,
#  ('outstanding', ';'): 2,
#  ('outstanding', 'Common'): 1,
#  ('outstanding', 'Options'): 4,
#  ('outstanding', 'immediately'): 1,
#  ('outstanding', 'indebtedness'): 1,
#  ('outstanding', 'shares'): 1,
#  ('outstanding', 'voting'): 2,
#  ('overnight', 'courier'): 1,
#  ('own', ','): 1,
#  ('own', 'account'): 1,
#  ('owner', '”'): 1,
#  ('owns', 'or'): 1,
#  ('page', ','): 2,
#  ('page', 'follows'): 1,
#  ('paid', 'per'): 1,
#  ('par', 'with'): 2,
#  ('part', 'of'): 2,
#  ('part', 'or'): 1,
#  ('participation', 'in'): 1,
#  ('particularly', 'as'): 1,
#  ('parties', 'acknowledge'): 1,
#  ('parties', 'agree'): 1,
#  ('partner', ','): 1,
#  ('partners', 'or'): 1,
#  ('party', 'or'): 2,
#  ('party', 'to'): 1,
#  ('party', 'without'): 1,
#  ('party', '’'): 1,
#  ('patents', ','): 1,
#  ('pay', 'the'): 1,
#  ('payable', 'in'): 1,
#  ('payable', 'on'): 2,
#  ('payable', 'to'): 4,
#  ('payment', ','): 2,
#  ('payment', 'and'): 1,
#  ('payment', 'by'): 1,
#  ('payment', 'of'): 1,
#  ('payments', ';'): 1,
#  ('payments', 'are'): 1,
#  ('payments', 'described'): 1,
#  ('payments', 'for'): 3,
#  ('payments', 'in'): 1,
#  ('payments', 'that'): 1,
#  ('payments', 'to'): 1,
#  ('pays', 'a'): 2,
#  ('per', 'share'): 5,
#  ('per', 'share.'): 1,
#  ('perform', 'its'): 1,
#  ('performance', 'and'): 1,
#  ('performance', 'by'): 1,
#  ('performance', 'of'): 1,
#  ('period', 'of'): 1,
#  ('permit', ','): 1,
#  ('permit', 'full'): 1,
#  ('permitted', 'by'): 1,
#  ('person', '”'): 1,
#  ('personally', 'or'): 1,
#  ('plan.', '3.Company'): 1,
#  ('portion', 'of'): 3,
#  ('possesses', '('): 1,
#  ('post-money', 'valuation.'): 1,
#  ('postage', 'prepaid'): 1,
#  ('power', 'and'): 2,
#  ('power', 'of'): 1,
#  ('power', 'represented'): 1,
#  ('pre-money', 'or'): 1,
#  ('preference', 'and'): 1,
#  ('preference', 'payments'): 1,
#  ('preferences', ')'): 1,
#  ('preferences', 'and'): 1,
#  ('prejudiced', ','): 1,
#  ('prepaid', ','): 1,
#  ('present', 'intention'): 1,
#  ('price', 'for'): 1,
#  ('price', 'per'): 4,
#  ('price-based', 'anti-dilution'): 1,
#  ('principal', 'purpose'): 1,
#  ('principles', 'of'): 2,
#  ('prior', 'breach'): 1,
#  ('prior', 'to'): 6,
#  ('prior', 'written'): 1,
#  ('priority', 'to'): 1,
#  ('privileges', ','): 1,
#  ('pro', 'rata'): 2,
#  ('proceeds', 'from'): 1,
#  ('processes', 'and'): 1,
#  ('promised', 'but'): 1,
#  ('promised', 'pursuant'): 1,
#  ('promissory', 'notes'): 3,
#  ('properties', 'and'): 1,
#  ('property', ','): 1,
#  ('property', 'rights'): 1,
#  ('proportion', 'to'): 1,
#  ('proposed', 'to'): 1,
#  ('prospectively', 'operate'): 1,
#  ('protection', ','): 1,
#  ('provided', ','): 2,
#  ('provided', 'further'): 1,
#  ('provided', 'that'): 3,
#  ('provision', '('): 1,
#  ('provision', 'of'): 2,
#  ('provisions', 'of'): 4,
#  ('public', 'offering'): 1,
#  ('purchased', 'by'): 1,
#  ('purchasers', 'of'): 1,
#  ('purchases', ','): 1,
#  ('purchasing', 'this'): 1,
#  ('purpose', 'of'): 2,
#  ('purpose', 'other'): 1,
#  ('purposes', '('): 1,
#  ('purposes', ','): 2,
#  ('purposes', 'of'): 3,
#  ('purposes', 'this'): 1,
#  ('pursuant', 'to'): 6,
#  ('qualifications', 'or'): 1,
#  ('qualify', 'as'): 2,
#  ('raising', 'capital'): 1,
#  ('rata', 'basis'): 1,
#  ('rata', 'to'): 1,
#  ('reason', 'held'): 1,
#  ('reasonable', 'terms'): 1,
#  ('reasonably', 'be'): 1,
#  ('receive', 'a'): 3,
#  ('receive', 'as'): 1,
#  ('receive', 'its'): 2,
#  ('receive', 'notice'): 1,
#  ('received', 'in'): 1,
#  ('receiving', 'Cash-Out'): 1,
#  ('receiving', 'Conversion'): 1,
#  ('receiving', 'Proceeds'): 1,
#  ('reddif.com', 'INVESTOR'): 1,
#  ('reddit', '@'): 1,
#  ('reddit', 'Email'): 1,
#  ('reduce', 'the'): 2,
#  ('reduction', '('): 1,
#  ('refers', 'to'): 1,
#  ('regard', 'to'): 1,
#  ('registered', 'mail'): 1,
#  ('registered', 'under'): 2,
#  ('registration', 'requirements'): 1,
#  ('registration', 'statement'): 1,
#  ('regulation', 'applicable'): 2,
#  ('reincorporation', 'to'): 1,
#  ('related', 'to'): 1,
#  ('related', 'transactions'): 4,
#  ('relating', 'to'): 2,
#  ('relevant', 'address'): 1,
#  ('relieving', 'the'): 1,
#  ('remain', 'operative'): 1,
#  ('remaining', 'provisions'): 1,
#  ('reorganization', ','): 2,
#  ('reorganization', 'for'): 1,
#  ('representations', 'and'): 1,
#  ('represented', 'by'): 1,
#  ('required', 'in'): 1,
#  ('required', 'or'): 1,
#  ('requirement', 'or'): 1,
#  ('requirements', 'is'): 1,
#  ('resale', 'in'): 1,
#  ('reserved', ','): 1,
#  ('resold', 'unless'): 1,
#  ('respect', ','): 1,
#  ('respect', 'to'): 4,
#  ('respective', 'tax'): 1,
#  ('restricted', 'stock'): 1,
#  ('restrictions', 'as'): 1,
#  ('result', 'in'): 2,
#  ('result', 'of'): 1,
#  ('resulting', 'entity'): 1,
#  ('retain', ','): 1,
#  ('return', 'the'): 1,
#  ('returns', 'or'): 1,
#  ('revenue', 'of'): 1,
#  ('right', 'to'): 6,
#  ('rights', ','): 2,
#  ('rights', 'and'): 1,
#  ('rights', 'generally'): 2,
#  ('rights', 'in'): 1,
#  ('rights', 'may'): 1,
#  ('rights', 'necessary'): 1,
#  ('rights', 'of'): 2,
#  ('rights', 'to'): 2,
#  ('risk', 'of'): 1,
#  ('risks', 'of'): 1,
#  ('rule', 'or'): 2,
#  ('s', ')'): 2,
#  ('s', 'Capital'): 1,
#  ('s', 'address'): 1,
#  ('s', 'board'): 1,
#  ('s', 'business'): 1,
#  ('s', 'consent'): 1,
#  ('s', 'corporate'): 1,
#  ('s', 'creditors'): 1,
#  ('s', 'domicile.'): 1,
#  ('s', 'failure'): 1,
#  ('s', 'financial'): 1,
#  ('s', 'first'): 1,
#  ('s', 'price'): 1,
#  ('s', 'right'): 2,
#  ('s', 'securityholders'): 2,
#  ('sale', ','): 1,
#  ('same', 'choice'): 1,
#  ('same', 'documents'): 1,
#  ('same', 'management'): 1,
#  ('same', 'manner'): 1,
#  ('same', 'manner.'): 1,
#  ('same', 'time.'): 1,
#  ('same', 'with'): 1,
#  ('same', '“'): 1,
#  ('same.', 'The'): 1,
#  ('satisfy', 'any'): 1,
#  ('secrets', ','): 1,
#  ('section', '3'): 1,
#  ('securities', '('): 1,
#  ('securities', ','): 1,
#  ('securities', 'are'): 1,
#  ('securities', 'have'): 1,
#  ('securities', 'issued'): 1,
#  ('securities', 'laws'): 3,
#  ('securities', 'of'): 3,
#  ('securities', 'that'): 1,
#  ('securities', 'to'): 1,
#  ('securityholders', ','): 1,
#  ('securityholders', 'are'): 1,
#  ('securityholders', 'who'): 1,
#  ('selling', ','): 1,
#  ('sells', 'Preferred'): 1,
#  ('sent', 'by'): 1,
#  ('series', 'of'): 7,
#  ('service', 'marks'): 1,
#  ('setting', 'aside'): 1,
#  ('share', 'equal'): 2,
#  ('share', 'liquidation'): 1,
#  ('share', 'of'): 2,
#  ('share.', '“'): 1,
#  ('shares', 'have'): 1,
#  ('shares', 'of'): 16,
#  ('shares', 'the'): 1,
#  ('sheet', ')'): 1,
#  ('sheet', 'for'): 1,
#  ('signature', 'page'): 2,
#  ('similar', 'Company'): 1,
#  ('similar', 'as-converted'): 1,
#  ('similar', 'in'): 1,
#  ('similar', 'liquidation'): 2,
#  ('similar', 'securities'): 1,
#  ('similar', '“'): 1,
#  ('solely', 'for'): 1,
#  ('solicited', '('): 1,
#  ('space', 'corporation'): 1,
#  ('specific', 'instrument.'): 1,
#  ('standard', 'non-participating'): 1,
#  ('standing', 'under'): 1,
#  ('state', 'income'): 2,
#  ('state', 'of'): 1,
#  ('state', 'securities'): 2,
#  ('statement', 'filed'): 1,
#  ('statements', ')'): 1,
#  ('statute', ','): 2,
#  ('stock', ','): 1,
#  ('stock', 'awards'): 1,
#  ('stock', 'consideration'): 1,
#  ('stock', 'for'): 1,
#  ('stock', 'of'): 1,
#  ('stockholder', 'or'): 1,
#  ('stockholders', ','): 1,
#  ('subject', 'to'): 3,
#  ('submitted', 'to'): 1,
#  ('subsequently', 'modified'): 1,
#  ('substantially', 'all'): 1,
#  ('such', ','): 1,
#  ('such', 'Change'): 1,
#  ('such', 'Equity'): 1,
#  ('such', 'Investor'): 1,
#  ('such', 'Liquidity'): 2,
#  ('such', 'Promised'): 1,
#  ('such', 'Safes'): 1,
#  ('such', 'amendment'): 1,
#  ('such', 'applicable'): 1,
#  ('such', 'convertible'): 1,
#  ('such', 'dividend'): 1,
#  ('such', 'documents'): 2,
#  ('such', 'event'): 1,
#  ('such', 'holders'): 1,
#  ('such', 'investment'): 3,
#  ('such', 'jurisdiction.'): 1,
#  ('such', 'knowledge'): 1,
#  ('such', 'other'): 3,
#  ('such', 'party'): 1,
#  ('such', 'payments'): 1,
#  ('such', 'provision'): 1,
#  ('such', 'reduction'): 1,
#  ('such', 'registration'): 1,
#  ('such', 'securities'): 1,
#  ('such', 'term'): 2,
#  ('such', 'terms'): 1,
#  ('such', 'transaction'): 2,
#  ('such', 'violation'): 1,
#  ('such', 'violations'): 1,
#  ('sufficient', 'legal'): 1,
#  ('sufficient', 'when'): 1,
#  ('surviving', 'or'): 1,
#  ('suspension', ','): 1,
#  ('tax', 'purposes'): 4,
#  ('tax', 'returns'): 1,
#  ('tax-free', 'reorganization'): 2,
#  ('term', '('): 1,
#  ('term', 'is'): 1,
#  ('term', 'sheet'): 2,
#  ('terminate', '('): 1,
#  ('termination', 'of'): 4,
#  ('terms', ')'): 1,
#  ('terms', ','): 2,
#  ('terms', 'described'): 2,
#  ('terms', 'will'): 1,
#  ('terms.', '1.Events'): 1,
#  ('terms.', 'The'): 1,
#  ('tesla', ','): 1,
#  ('than', '50'): 2,
#  ('than', ':'): 1,
#  ('than', 'a'): 1,
#  ('than', 'any'): 1,
#  ('than', 'tax'): 1,
#  ('than', 'with'): 1,
#  ('that', 'any'): 1,
#  ('that', 'are'): 3,
#  ('that', 'exceed'): 1,
#  ('that', 'for'): 1,
#  ('that', 'have'): 1,
#  ('that', 'if'): 1,
#  ('that', 'is'): 2,
#  ('that', 'neither'): 1,
#  ('that', 'such'): 3,
#  ('that', 'the'): 4,
#  ('that', 'this'): 2,
#  ('that', 'with'): 1,
#  ('that', 'would'): 1,
#  ('the', 'Cash-Out'): 1,
#  ('the', 'Company'): 43,
#  ('the', 'Company.'): 2,
#  ('the', 'Dissolution'): 2,
#  ('the', 'Dividend'): 1,
#  ('the', 'Equity'): 6,
#  ('the', 'Internal'): 1,
#  ('the', 'Investor'): 32,
#  ('the', 'Investor.'): 1,
#  ('the', 'Liquidity'): 4,
#  ('the', 'Post-Money'): 2,
#  ('the', 'Purchase'): 7,
#  ('the', 'Safe'): 4,
#  ('the', 'Securities'): 6,
#  ('the', 'Standard'): 2,
#  ('the', 'State'): 1,
#  ('the', 'U.S.'): 1,
#  ('the', 'Unissued'): 4,
#  ('the', 'acceleration'): 1,
#  ('the', 'amount'): 3,
#  ('the', 'applicable'): 3,
#  ('the', 'assets'): 1,
#  ('the', 'authorization'): 1,
#  ('the', 'automatic'): 2,
#  ('the', 'basis'): 1,
#  ('the', 'benefit'): 1,
#  ('the', 'calculation'): 1,
#  ('the', 'capital'): 1,
#  ('the', 'case'): 1,
#  ('the', 'cash'): 1,
#  ('the', 'closing'): 1,
#  ('the', 'conflicts'): 1,
#  ('the', 'consent'): 2,
#  ('the', 'consummation'): 2,
#  ('the', 'creation'): 1,
#  ('the', 'distribution'): 1,
#  ('the', 'dividend'): 1,
#  ('the', 'earliest'): 1,
#  ('the', 'economic'): 1,
#  ('the', 'election'): 2,
#  ('the', 'enforcement'): 2,
#  ('the', 'event'): 2,
#  ('the', 'execution'): 1,
#  ('the', 'extent'): 5,
#  ('the', 'foregoing'): 3,
#  ('the', 'form'): 2,
#  ('the', 'forms'): 1,
#  ('the', 'full'): 1,
#  ('the', 'greater'): 3,
#  ('the', 'holders'): 3,
#  ('the', 'identical'): 1,
#  ('the', 'initial'): 4,
#  ('the', 'investors'): 1,
#  ('the', 'issuance'): 1,
#  ('the', 'latter'): 1,
#  ('the', 'laws'): 2,
#  ('the', 'lowest'): 1,
#  ('the', 'majority-in-interest'): 1,
#  ('the', 'meaning'): 1,
#  ('the', 'merits'): 1,
#  ('the', 'number'): 3,
#  ('the', 'other'): 1,
#  ('the', 'outstanding'): 2,
#  ('the', 'part'): 2,
#  ('the', 'parties'): 1,
#  ('the', 'party'): 1,
#  ('the', 'payment'): 2,
#  ('the', 'per'): 1,
#  ('the', 'performance'): 1,
#  ('the', 'power'): 2,
#  ('the', 'price'): 2,
#  ('the', 'principal'): 1,
#  ('the', 'prior'): 1,
#  ('the', 'provisions'): 2,
#  ('the', 'purchasers'): 1,
#  ('the', 'purpose'): 1,
#  ('the', 'relevant'): 1,
#  ('the', 'remaining'): 1,
#  ('the', 'right'): 3,
#  ('the', 'rights'): 2,
#  ('the', 'same'): 8,
#  ('the', 'same.'): 1,
#  ('the', 'securities'): 1,
#  ('the', 'series'): 2,
#  ('the', 'shares'): 3,
#  ('the', 'signature'): 2,
#  ('the', 'suspension'): 1,
#  ('the', 'term'): 1,
#  ('the', 'termination'): 3,
#  ('the', 'terms'): 2,
#  ('the', 'time'): 1,
#  ('the', 'total'): 3,
#  ('the', 'transaction'): 1,
#  ('the', 'transactions'): 1,
#  ('the', 'underlying'): 1,
#  ('the', 'undersigned'): 1,
#  ('the', 'voting'): 1,
#  ('the', '“'): 7,
#  ('their', 'respective'): 1,
#  ('then', 'and'): 1,
#  ('then-outstanding', 'Safes'): 1,
#  ('there', 'is'): 4,
#  ('thereby.', '('): 1,
#  ('therefore', ','): 1,
#  ('thereof', ','): 1,
#  ('they', 'are'): 1,
#  ('this', 'Safe'): 36,
#  ('this', 'instrument'): 1,
#  ('this', 'manner'): 1,
#  ('this', 'specific'): 1,
#  ('those', '('): 1,
#  ('time', 'of'): 1,
#  ('time.', '('): 1,
#  ('time.', '5.Miscellaneous'): 1,
#  ('times', 'has'): 1,
#  ('to', ','): 3,
#  ('to', ':'): 2,
#  ('to', 'Common'): 1,
#  ('to', 'Company'): 1,
#  ('to', 'Section'): 2,
#  ('to', 'a'): 1,
#  ('to', 'agreements'): 1,
#  ('to', 'all'): 2,
#  ('to', 'any'): 5,
#  ('to', 'be'): 9,
#  ('to', 'bear'): 1,
#  ('to', 'certain'): 1,
#  ('to', 'change'): 1,
#  ('to', 'clause'): 1,
#  ('to', 'confer'): 1,
#  ('to', 'convert'): 1,
#  ('to', 'cover'): 1,
#  ('to', 'execute'): 1,
#  ('to', 'fill'): 1,
#  ('to', 'give'): 1,
#  ('to', 'have'): 1,
#  ('to', 'incur'): 1,
#  ('to', 'invalidate'): 1,
#  ('to', 'occur'): 1,
#  ('to', 'operate'): 1,
#  ('to', 'or'): 2,
#  ('to', 'own'): 1,
#  ('to', 'payment'): 1,
#  ('to', 'payments'): 2,
#  ('to', 'perform'): 1,
#  ('to', 'permit'): 1,
#  ('to', 'qualify'): 2,
#  ('to', 'receive'): 7,
#  ('to', 'satisfy'): 1,
#  ('to', 'section'): 1,
#  ('to', 'shares'): 1,
#  ('to', 'such'): 3,
#  ('to', 'the'): 43,
#  ('to', 'this'): 1,
#  ('to', 'treat'): 1,
#  ('to', 'vote'): 3,
#  ('to', 'which'): 3,
#  ('to', '“'): 1,
#  ('together', 'with'): 1,
#  ('total', 'Proceeds'): 1,
#  ('total', 'Purchase'): 2,
#  ('total', 'voting'): 1,
#  ('town', 'Email'): 1,
#  ('trade', 'names'): 1,
#  ('trade', 'secrets'): 1,
#  ('trademarks', ','): 1,
#  ('transaction', 'documents'): 1,
#  ('transaction', 'or'): 5,
#  ('transactions', ','): 1,
#  ('transactions', 'contemplated'): 1,
#  ('transactions', 'in'): 2,
#  ('transactions', 'retain'): 1,
#  ('transactions', 'with'): 1,
#  ('transferable', 'or'): 1,
#  ('treat', 'this'): 1,
#  ('treated', 'as'): 1,
#  ('treating', 'the'): 1,
#  ('treats', 'all'): 1,
#  ('under', 'Section'): 2,
#  ('under', 'any'): 2,
#  ('under', 'applicable'): 1,
#  ('under', 'common'): 1,
#  ('under', 'the'): 6,
#  ('underlying', 'securities'): 1,
#  ('undersigned', 'have'): 1,
#  ('understandings', 'made'): 1,
#  ('underwritten', 'initial'): 1,
#  ('unenforceable', ','): 1,
#  ('ungranted', 'Options'): 1,
#  ('unless', 'an'): 1,
#  ('unless', 'they'): 1,
#  ('until', 'shares'): 1,
#  ('unvested.', '“'): 1,
#  ('up', 'of'): 1,
#  ('valid', 'and'): 2,
#  ('validly', 'existing'): 1,
#  ('valuation', ','): 1,
#  ('valuation.', '“'): 1,
#  ('variations', 'for'): 1,
#  ('vegito', 'blue'): 1,
#  ('venture', 'capital'): 1,
#  ('vested', 'or'): 1,
#  ('view', 'to'): 1,
#  ('violate', 'any'): 1,
#  ('violation', 'of'): 1,
#  ('violation', 'or'): 1,
#  ('violations', 'or'): 1,
#  ('void', 'and'): 1,
#  ('void', 'this'): 1,
#  ('voluntary', 'or'): 1,
#  ('voluntary', 'termination'): 1,
#  ('vote', 'for'): 2,
#  ('vote', 'or'): 1,
#  ('voting', 'power'): 1,
#  ('voting', 'securities'): 3,
#  ('waived', 'or'): 2,
#  ('waiver', 'or'): 1,
#  ('warranties', 'and'): 1,
#  ('warrants', 'or'): 1,
#  ('when', 'delivered'): 1,
#  ('where', ','): 1,
#  ('where', 'the'): 1,
#  ('whether', 'voluntary'): 1,
#  ('which', 'any'): 1,
#  ('which', 'is'): 1,
#  ('which', 'it'): 2,
#  ('which', 'the'): 5,
#  ('which', 'will'): 2,
#  ('while', 'this'): 1,
#  ('who', 'are'): 1,
#  ('who', 'directly'): 1,
#  ('who', 'have'): 1,
#  ('whole', ','): 1,
#  ('whole', 'or'): 1,
#  ('whose', 'Safes'): 1,
#  ('will', 'anything'): 1,
#  ('will', 'automatically'): 4,
#  ('will', 'be'): 7,
#  ('will', 'equal'): 1,
#  ('will', 'execute'): 1,
#  ('will', 'not'): 3,
#  ('will', 'pay'): 1,
#  ('will', 'remain'): 1,
#  ('winding', 'up'): 1,
#  ('with', ','): 5,
#  ('with', 'a'): 3,
#  ('with', 'all'): 1,
#  ('with', 'appropriate'): 1,
#  ('with', 'its'): 2,
#  ('with', 'payments'): 2,
#  ('with', 'postage'): 1,
#  ('with', 'respect'): 4,
#  ('with', 'the'): 9,
#  ('with', 'this'): 1,
#  ('withhold', 'consent'): 1,
#  ('within', 'the'): 2,
#  ('without', 'any'): 1,
#  ('without', 'double-'): 1,
#  ('without', 'double-counting'): 1,
#  ('without', 'impairing'): 1,
#  ('without', 'limitation'): 6,
#  ('without', 'regard'): 1,
#  ('without', 'relieving'): 1,
#  ('without', 'the'): 3,
#  ('would', 'be'): 1,
#  ('would', 'otherwise'): 1,
#  ('would', 'prospectively'): 1,
#  ('written', 'consent'): 2,
#  ('written', 'notice.'): 1,
#  ('x', ')'): 1,
#  ('y', ')'): 1,
#  ('’', 'rights'): 2,
#  ('’', 's'): 16,
#  ('“', 'Capital'): 1,
#  ('“', 'Cash-Out'): 1,
#  ('“', 'Change'): 1,
#  ('“', 'Common'): 1,
#  ('“', 'Company'): 1,
#  ('“', 'Conversion'): 1,
#  ('“', 'Converting'): 1,
#  ('“', 'Discount'): 1,
#  ('“', 'Dissolution'): 1,
#  ('“', 'Dividend'): 1,
#  ('“', 'Equity'): 1,
#  ('“', 'Initial'): 1,
#  ('“', 'Investor'): 1,
#  ('“', 'Liquidity'): 3,
#  ('“', 'Majority-in-interest'): 1,
#  ('“', 'Options'): 1,
#  ('“', 'Post-Money'): 2,
#  ('“', 'Preferred'): 1,
#  ('“', 'Proceeds'): 1,
#  ('“', 'Promised'): 1,
#  ('“', 'Purchase'): 1,
#  ('“', 'SECURITIES'): 1,
#  ('“', 'Safe'): 2,
#  ('“', 'SafePreferred'): 1,
#  ('“', 'Standard'): 1,
#  ('“', 'Unissued'): 1,
#  ('“', 'as-converted'): 1,
#  ('“', 'beneficial'): 1,
#  ('“', 'group'): 1,
#  ('“', 'person'): 1,
#  ('“', 'this'): 1,
#  ('”', '('): 2,
#  ('”', ')'): 5,
#  ('”', 'and'): 2,
#  ('”', 'as'): 1,
#  ('”', 'includes'): 2,
#  ('”', 'is'): 3,
#  ('”', 'mean'): 1,
#  ('”', 'means'): 15,
#  ('”', 'or'): 1,
#  ('”', 'payments'): 1,
#  ('”', 'refers'): 1,
#  ('”', '“'): 1}
